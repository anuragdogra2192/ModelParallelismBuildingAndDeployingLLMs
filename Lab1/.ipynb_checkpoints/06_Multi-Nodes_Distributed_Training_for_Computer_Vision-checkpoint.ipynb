# %% [markdown]
# <img src="./images/DLI_Header.png" style="width: 400px;">

# %% [markdown]
# # 6.0 Multi-Nodes Distributed Training for Computer Vision
#
# In this notebook, we will learn how to train a simple Image Classifier in distributed mode.
# We will first implement a vanilla pipeline parallel distribution. Then, we will use Microsoft's [DeepSpeed Library](https://www.deepspeed.ai/) for model distribution and optimization techniques.
#
# ## The goals
#
# The goals of this notebook are to:
# * Learn how to train a vanilla CNN
# * Port the code to DeepSpeed library
# * Scale training using Data parallel distribution
# * Optimize training with DeepSpeed autotuning and Zero Redundancy Optimizer
#
#
# **[6.1 Convolutional Neural Network for Image Classification on CIFAR-10](#6.1-Convolutional-Neural-Network-for-Image-Classification-on-CIFAR-10)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[6.1.1 The dataset](#6.1.1-The-dataset)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.1.2 Convolutional Neural Network](#612-convolutional-neural-network)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.1.3 Naive Model Distribution](#613-naive-model-distribution)<br>
# **[6.2 Distributed Training with DeepSpeed](#6.2-Distributed-Training-with-DeepSpeed)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[6.2.1 Make the code run with DeepSpeed](#621-make-the-code-run-with-deepspeed)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.2.2 Scale-out training with Data Parallelism](#622-scale-out-training-with-data-parallelism)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.2.3 Zero Redundancy Optimizer ](#623-zero-redundancy-optimizer)<br>
#
# ### Cancel Previous Running/Pending Jobs
#
# Before moving on, check that no jobs are still running or waiting on the SLURM queue. Let's check the SLURM jobs queue by executing the following cell:

# %%
# Check the SLURM jobs queue 
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# If there are still jobs running or pending, execute the following cell to cancel all the user's jobs using the `scancel` command.

# %%
# Cancel admin user jobs
# !scancel -u $USER

# Check again the SLURM jobs queue (should be either empty, or the status TS column should be CG)
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# ---
# # 6.1 Convolutional Neural Network for Image Classification on CIFAR-10
#
# ## 6.1.1 The dataset
#
#
# The [CIFAR-10 Dataset](https://www.cs.toronto.edu/~kriz/cifar.html) consists of 60K images (50K for training and 10K for testing). Images are 32 by 32 pixels labelled with 10 classes: plane, car, bird, cat, deer, dog, frog, horse, ship and truck.
# In this lab, we will train a simple Convolutional Neural Network to classify CIFAR-10 images.
#
# To download the dataset, we will use the [Torchvision](https://pytorch.org/vision/stable/index.html) package, a Pytorch library that contains popular datasets, model architectures, and common image transformations for Computer Vision.
#
# <img src="images/CIFAR-10.jpg" width="350" />
#
# Let's first import the relevant libraries by executing the next cell.

# %%
# import the relevant libraries
import torch
import torchvision
from IPython.display import display_html

# disable P2P connections for single-node DeepSpeed runs
# %env NCCL_P2P_DISABLE=1

def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# define an image transform 
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
# Out:
# env: NCCL_P2P_DISABLE=1

# %% [markdown]
# Execute the next 2 cells to download the training and test CIFAR10 corpus.

# %%
# Download the CIFAR10 training dataset
trainset = torchvision.datasets.CIFAR10(root='./data',
                                        train=True,
                                        download=True,
                                        transform=transform)
trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=64,
                                          shuffle=True,
                                          num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# Download the CIFAR10 test dataset
testset = torchvision.datasets.CIFAR10(root='./data',
                                       train=False,
                                       download=True,
                                       transform=transform)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=64,
                                         shuffle=False,
                                         num_workers=2)
# Out:
# Files already downloaded and verified

# %% [markdown]
# Let's have a look at some examples:

# %%
# Show some random training images
import matplotlib.pyplot as plt
import numpy as np

def imshow(images, labels):
    for i in range(8): 
        img = images[i] / 2 + 0.5
        npimg = img.numpy()
        plt.subplot(2,4,i+1)
        plt.imshow(np.transpose(npimg, (1, 2 , 0)));
        plt.axis('off');
        plt.title(classes[labels[i]])

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# get some training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
# Show images
imshow(images,labels)

# %% [markdown]
# ## 6.1.2 Convolutional Neural Network
#
# Let's define a neural network with 2 convolutional layers, first followed by a pooling layer then 3 fully connected layers.

# %%
# Define the CNN
import torch.nn as nn
import torch.nn.functional as F

class CNN_Net(nn.Module):
    def __init__(self):
        super(CNN_Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

cnn_net = CNN_Net()

# %%
# Copy the model to GPU 0
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
cnn_net.to(device)
# Out:
# CNN_Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
# Let's have a look at the Convolutional Neural Network
from torchsummary import summary
summary(cnn_net,input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             456
#          MaxPool2d-2            [-1, 6, 14, 14]               0
#             Conv2d-3           [-1, 16, 10, 10]           2,416
#          MaxPool2d-4             [-1, 16, 5, 5]               0
#             Linear-5                  [-1, 120]          48,120
#             Linear-6                   [-1, 84]          10,164
#             Linear-7                   [-1, 10]             850
# ================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.06
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.31
# ----------------------------------------------------------------

# %% [markdown]
# Let's define the optimizer and hyperparameters. We will use the Stochastic Gradient Descent (SGD) with momentum optimizer.

# %%
# Define the hyperparameters
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter 

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cnn_net.parameters(), lr=0.001,momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# Tensorboard event recording directory 
writer = SummaryWriter('nemo/cifar10')

log_interval=100
batch_size=64
epochs=2

# %%
# Train the CNN
for epoch in range(epochs): 
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = cnn_net(inputs)
        loss = criterion(outputs, labels)
        
        # Backward pass
        loss.backward()
        optimizer.step()     
        
        # print the loss and accuracy metrics log_interval mini-batches
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        if i % log_interval == (log_interval - 1):  
            print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / log_interval, 100.*correct/total))
            writer.add_scalar("Training Cross Entropy Loss", running_loss / log_interval, i + 1)
            writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
            running_loss = 0.0
    # print the last iterations 
    print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / ((i % log_interval) + 1), 100.*correct/total))
    writer.add_scalar("Training Cross Entropy Loss", running_loss / ((i % log_interval) + 1), i + 1)
    writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)

print('Training Done')
writer.add_graph(cnn_net, inputs)
writer.flush()
writer.close()
# Out:
# [epoch 0, iterations   100] loss: 2.303 accuracy: 9.921875 %
# [epoch 0, iterations   200] loss: 2.302 accuracy: 10.289062 %
# [epoch 0, iterations   300] loss: 2.300 accuracy: 10.161458 %
# [epoch 0, iterations   400] loss: 2.299 accuracy: 10.199219 %
# [epoch 0, iterations   500] loss: 2.298 accuracy: 10.050000 %
# [epoch 0, iterations   600] loss: 2.295 accuracy: 10.286458 %
# [epoch 0, iterations   700] loss: 2.291 accuracy: 10.738839 %
# [epoch 0, iterations   782] loss: 2.286 accuracy: 11.224000 %
# [epoch 1, iterations   100] loss: 2.276 accuracy: 16.562500 %
# [epoch 1, iterations   200] loss: 2.258 accuracy: 17.109375 %
# [epoch 1, iterations   300] loss: 2.230 accuracy: 17.177083 %
# [epoch 1, iterations   400] loss: 2.182 accuracy: 17.558594 %
# [epoch 1, iterations   500] loss: 2.145 accuracy: 18.009375 %
# [epoch 1, iterations   600] loss: 2.101 accuracy: 18.442708 %
# [epoch 1, iterations   700] loss: 2.068 accuracy: 19.113839 %
# [epoch 1, iterations   782] loss: 2.029 accuracy: 19.728000 %
# Training Done

# %% [markdown]
# ### Monitor Training and Inspect the Model on Tensorboard
#
# We set the arguments for recording Tensorboard events in the previous CNN training. The training loss is available under the name `cifar10`. We can also visualize the model and navigate throughout its layers on the `GRAPHS` tab.
#
# <img src="images/CNN.png" width="750"/>
#
# Execute the next cell to create a link to Tensorboard for your browser. Then, click the link to see graphs of experiment metrics saved in the specified `Tensorboard` directory.

# %%
# %%js
# const href = window.location.hostname +'/tensorboard/';
# let a = document.createElement('a');
# let link = document.createTextNode('Open Tensorboard!');
# a.appendChild(link);
# a.href = "http://" + href;
# a.style.color = "navy"
# a.target = "_blank"
# element.append(a);

# %% [markdown]
# ### Evaluate The Trained Model
#
# Let's evaluate the trained model on the CIFAR-10 test dataset. Execute the following cell to evaluate the accuracy on the test set. Accuracy detail per class will also be shown.

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = cnn_net(images.to(device))
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels.to(device)).sum().item()
        c = (predicted == labels.to(device)).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

print('Accuracy of the network on the 10000 test images: %2f %%' %
      (100 * correct / total))
for i in range(10):
    print('Accuracy of %5s : %2f %%' %
          (classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of the network on the 10000 test images: 26.280000 %
# Accuracy of plane : 46.428571 %
# Accuracy of   car : 16.000000 %
# Accuracy of  bird : 0.000000 %
# Accuracy of   cat : 5.479452 %
# Accuracy of  deer : 0.000000 %
# Accuracy of   dog : 8.474576 %
# Accuracy of  frog : 83.928571 %
# Accuracy of horse : 18.750000 %
# Accuracy of  ship : 46.551724 %
# Accuracy of truck : 33.333333 %

# %% [markdown]
# # 6.1.3 Naive Model Distribution
#
# Let's now implement a naive pipeline parallel distribution of the previous CNN model. To do so, we need to explicitly place each layer into the device and implement the forward pass, accordingly moving the corresponding outputs to match devices accordingly.

# %% [markdown]
# We will run the CNN model on two GPUs by placing: conv1 + pooling on GPU0 and conv2 + fc1 + fc2+ fc3 on GPU1.
# We will use torch [`torch.tensor.to`](https://pytorch.org/docs/stable/generated/torch.Tensor.to.html#torch.Tensor.to) to convert tensors to cuda and place them to the desired device.
#
# Have a look at modified class on the defined `Net_Parallel` class:

# %%
# Define the CNN
import torch.nn as nn
import torch.nn.functional as F

class Net_Parallel(nn.Module):
    def __init__(self):
        super(Net_Parallel, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5).to('cuda:0')               # Changed here
        self.pool = nn.MaxPool2d(2, 2).to('cuda:0')                # Changed here
        self.conv2 = nn.Conv2d(6, 16, 5).to('cuda:1')              # Changed here
        self.fc1 = nn.Linear(16 * 5 * 5, 120).to('cuda:1')         # Changed here
        self.fc2 = nn.Linear(120, 84).to('cuda:1')                 # Changed here
        self.fc3 = nn.Linear(84, 10).to('cuda:1')                  # Changed here

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x.to('cuda:0'))))          # Changed here
        x = self.pool(F.relu(self.conv2(x.to('cuda:1'))))          # Changed here
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

cnn_net_pp = Net_Parallel()

# %% [markdown]
# Similar to the previous training execution, run the next 2 cells to define the optimizer/hyperparameters and then launch the training.

# %%
# Define the hyperparameters
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cnn_net_pp.parameters(), lr=0.001,momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# Tensorboard event recording directory 
writer_pp = SummaryWriter('nemo/cifar10_PP')                 

log_interval=100
batch_size=64
epochs=2

# %% [markdown]
# You can check the GPUs activity by running the next cell to open a terminal and the `watch nvidia-smi` command.

# %%
# %%html
#
# <pre>
#    Step 1: Open a terminal session by following the <a href="", data-commandlinker-command="terminal:create-new">Terminal link</a>
#    Step 2: Check the GPUs: <font color="green">watch nvidia-smi</font>
# </pre
# Out:
# <pre>
#    Step 1: Open a terminal session by following the <a href="", data-commandlinker-command="terminal:create-new">Terminal link</a>
#    Step 2: Check the GPUs: <font color="green">watch nvidia-smi</font>
# </pre

# %% [markdown]
# Keep the terminal window opened and execute the next training.

# %%
# Train the CNN with pipeline parallel
for epoch in range(epochs): 
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)#device == cuda:0
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = cnn_net_pp(inputs.to('cuda:0'))                                # Changed here
        loss = criterion(outputs, labels.to('cuda:1'))                           # Changed here
        # Backward pass
        loss.backward()
        optimizer.step()
        torch.cuda.reset_max_memory_allocated(0)
        # print the loss and accuracy metrics log_interval mini-batches
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels.to('cuda:1')).sum().item()                 # Changed here
        if i % log_interval == (log_interval - 1):  
            print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / log_interval, 100.*correct/total))
            writer_pp.add_scalar("Training Cross Entropy Loss", running_loss / log_interval, i + 1)
            writer_pp.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
            running_loss = 0.0
    # print the last iterations 
    print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / ((i % log_interval) + 1), 100.*correct/total))
    writer.add_scalar("Training Cross Entropy Loss", running_loss / ((i % log_interval) + 1), i + 1)
    writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)

print('Training Done')
writer_pp.add_graph(cnn_net_pp, inputs)
writer_pp.flush()
writer_pp.close()
# Out:
# [epoch 0, iterations   100] loss: 2.020 accuracy: 26.593750 %
# [epoch 0, iterations   200] loss: 2.005 accuracy: 25.820312 %
# [epoch 0, iterations   300] loss: 1.989 accuracy: 26.114583 %
# [epoch 0, iterations   400] loss: 1.965 accuracy: 26.496094 %
# [epoch 0, iterations   500] loss: 1.956 accuracy: 27.021875 %
# [epoch 0, iterations   600] loss: 1.937 accuracy: 27.346354 %
# [epoch 0, iterations   700] loss: 1.906 accuracy: 27.723214 %
# [epoch 0, iterations   782] loss: 1.889 accuracy: 28.194000 %
# [epoch 1, iterations   100] loss: 1.852 accuracy: 33.578125 %
# [epoch 1, iterations   200] loss: 1.825 accuracy: 33.187500 %
# [epoch 1, iterations   300] loss: 1.793 accuracy: 33.729167 %
# [epoch 1, iterations   400] loss: 1.772 accuracy: 34.171875 %
# [epoch 1, iterations   500] loss: 1.743 accuracy: 34.553125 %
# [epoch 1, iterations   600] loss: 1.699 accuracy: 35.156250 %
# [epoch 1, iterations   700] loss: 1.675 accuracy: 35.787946 %
# [epoch 1, iterations   782] loss: 1.645 accuracy: 36.282000 %
# Training Done

# %% [markdown]
# # 6.2 Distributed Training with DeepSpeed
#
# The DeepSpeed library is a Deep Learning optimization library for distributed training on several different hardware sizes ranging from a single GPU to low-end clusters, going up to massive supercomputers.
#
# <img src="https://www.deepspeed.ai/assets/images/3d-parallelism.png" width="650" />
#
#
# - Distributed Training with Mixed Precision on Single-GPU/Multi-GPU/Multi-Node
# - Pipeline Parallelism and an integration with NeMo tensor parallel
# - Zero Redundancy Optimizer (ZeRO): Memory optimization techniques
# - ZeRO-Offload: Offloading data and compute to the CPU
# - Mixture of Experts (MoE)

# %% [markdown]
# ## 6.2.1 Make the code run with DeepSpeed
#
# The DeepSpeed engine can wrap neural networks defined as `torch.nn.module`. To write the previous Model with DeepSpeed, we will need to:
#
# - Instantiate the DeepSpeed Model engine and optimizer: Use the DeepSpeed initializer as follows:
# `model_engine, optimizer= deepspeed.initialize(args=args, model=Your_Network, model_parameters=parameters, training_data=trainset)`
# - The variable `args` should embed training arguments and the DeepSpeed arguments. We can use `deepspeed.add_config_arguments(parser)` to add the DeepSpeed arguments to our parser.
# - Refer to the DeepSpeed `model_engine` instead of `Your_Network` in the rest of the code.
# - For distributed training implementation with `torch.distributed.init_process_group(...)`, replace that with `deepspeed.init_distributed()`
#
# Learn more on how to write DeepSpeed models with the [dedicated DeepSpeed documentation.](https://www.deepspeed.ai/getting-started/#writing-deepspeed-models)
#
# DeepSpeed arguments can be passed throughout a JSON configuration file. Let's have a look at our the DeepSpeed configuration file:

# %%
# Have a look at the DeepSpeed config
# !cat code/moe/ds_config.json
# Out:
# {
#   "train_batch_size": 16,
#   "steps_per_print": 2000,
#   "optimizer": {
#     "type": "Adam",
#     "params": {
#       "lr": 0.001,
#       "betas": [
#         0.8,
#         0.999
#       ],
#       "eps": 1e-8,
#       "weight_decay": 3e-7
#     }
#   },
#   "scheduler": {
#     "type": "WarmupLR",
#     "params": {
#       "warmup_min_lr": 0,
#       "warmup_max_lr": 0.001,
#       "warmup_num_steps": 1000
#     }
#   },
#   "gradient_clipping": 1.0,
#   "prescale_gradients": false,
#   "fp16": {
#       "enabled": true,
#       "fp16_master_weights_and_grads": false,
#       "loss_scale": 0,
#       "loss_scale_window": 500,
#       "hysteresis": 2,
#       "min_loss_scale": 1,
#       "initial_scale_power": 15
#   },
#   "wall_clock_breakdown": false,
#   "zero_optimization": {
#       "stage": 0,
#       "allgather_partitions": true,
#       "reduce_scatter": true,
#       "allgather_bucket_size": 50000000,
#       "reduce_bucket_size": 50000000,
#       "overlap_comm": true,
#       "contiguous_gradients": true,
#       "cpu_offload": false
#   }
#
# }

# %%
# import the relevant library
import deepspeed

# define the argument class, the training arguments, and DeepSpeed
class Args:
    log_interval=100 
    batch_size=64
    epochs=2
    deepspeed = True
    deepspeed_config = "code/moe/ds_config.json"
    local_rank= 0

args=Args()

# %%
# define the CNN network
cnn_net_ds = CNN_Net()

# Define the hyperparameters
parameters = filter(lambda p: p.requires_grad, cnn_net_ds.parameters())

# Wrap the CNN network with DeepSpeed
model_engine, optimizer, _, _ = deepspeed.initialize(args=args, model=cnn_net_ds, model_parameters=parameters, training_data=trainset)

# enable mixed precision
fp16 = model_engine.fp16_enabled()

device = model_engine.local_rank
criterion = nn.CrossEntropyLoss()

# Tensorboard event recording directory 
writer_ds = SummaryWriter('nemo/cifar10_DS')
# Out:
# [2024-03-21 22:44:15,832] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-21 22:44:15,833] [INFO] [distributed.py:36:init_distributed] Not using the DeepSpeed or torch.distributed launchers, attempting to detect MPI environment...
# [2024-03-21 22:44:17,192] [INFO] [distributed.py:85:mpi_discovery] Discovered MPI settings of world_rank=0, local_rank=0, world_size=1, master_addr=172.18.0.3, master_port=29500
# [2024-03-21 22:44:17,193] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2024-03-21 22:44:17,383] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py38_cu118/fused_adam...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/adam -isystem /usr/local/lib/python3.8/dist-packages/torch/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.8/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_80,code=compute_80 -gencode=arch=compute_80,code=sm_80 --compiler-options '-fPIC' -O3 -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -lineinfo --use_fast_math -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_80,code=compute_80 -std=c++14 -c /usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/adam/multi_tensor_adam.cu -o multi_tensor_adam.cuda.o
# [2/3] c++ -MMD -MF fused_adam_frontend.o.d -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/adam -isystem /usr/local/lib/python3.8/dist-packages/torch/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.8/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -c /usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/adam/fused_adam_frontend.cpp -o fused_adam_frontend.o
# [3/3] c++ fused_adam_frontend.o multi_tensor_adam.cuda.o -shared -L/usr/local/lib/python3.8/dist-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o fused_adam.so
# Time to load fused_adam op: 20.862108945846558 seconds
# [2024-03-21 22:44:38,973] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# [2024-03-21 22:44:38,974] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = FusedAdam
# [2024-03-21 22:44:38,975] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 optimizer with dynamic loss scale
# [2024-03-21 22:44:38,978] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2024-03-21 22:44:38,979] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2024-03-21 22:44:38,979] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7fa0e1f45610>
# [2024-03-21 22:44:38,980] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2024-03-21 22:44:38,980] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# [2024-03-21 22:44:38,981] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2024-03-21 22:44:38,981] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2024-03-21 22:44:38,982] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2024-03-21 22:44:38,982] [INFO] [config.py:1063:print]   amp_params ................... False
# [2024-03-21 22:44:38,983] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2024-03-21 22:44:38,983] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2024-03-21 22:44:38,983] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2024-03-21 22:44:38,984] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2024-03-21 22:44:38,984] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2024-03-21 22:44:38,984] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2024-03-21 22:44:38,985] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2024-03-21 22:44:38,985] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2024-03-21 22:44:38,986] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2024-03-21 22:44:38,986] [INFO] [config.py:1063:print]   dump_state ................... False
# [2024-03-21 22:44:38,986] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2024-03-21 22:44:38,986] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2024-03-21 22:44:38,987] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2024-03-21 22:44:38,987] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2024-03-21 22:44:38,987] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2024-03-21 22:44:38,988] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2024-03-21 22:44:38,988] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2024-03-21 22:44:38,988] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2024-03-21 22:44:38,989] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2024-03-21 22:44:38,989] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2024-03-21 22:44:38,990] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2024-03-21 22:44:38,990] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2024-03-21 22:44:38,990] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# [2024-03-21 22:44:38,990] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
# [2024-03-21 22:44:38,991] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2024-03-21 22:44:38,991] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2024-03-21 22:44:38,992] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2024-03-21 22:44:38,992] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2024-03-21 22:44:38,992] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2024-03-21 22:44:38,993] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2024-03-21 22:44:38,993] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2024-03-21 22:44:38,993] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2024-03-21 22:44:38,994] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2024-03-21 22:44:38,994] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2024-03-21 22:44:38,994] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2024-03-21 22:44:38,995] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2024-03-21 22:44:38,995] [INFO] [config.py:1063:print]   pld_params ................... False
# [2024-03-21 22:44:38,995] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2024-03-21 22:44:38,996] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2024-03-21 22:44:38,996] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2024-03-21 22:44:38,996] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2024-03-21 22:44:38,997] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2024-03-21 22:44:38,997] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2024-03-21 22:44:38,997] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2024-03-21 22:44:38,998] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2024-03-21 22:44:38,998] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2024-03-21 22:44:38,998] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2024-03-21 22:44:38,999] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2024-03-21 22:44:38,999] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2024-03-21 22:44:38,999] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2024-03-21 22:44:38,999] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2024-03-21 22:44:39,000] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2024-03-21 22:44:39,000] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2024-03-21 22:44:39,000] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2024-03-21 22:44:39,001] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2024-03-21 22:44:39,001] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2024-03-21 22:44:39,001] [INFO] [config.py:1063:print]   train_batch_size ............. 16
# [2024-03-21 22:44:39,002] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  16
# [2024-03-21 22:44:39,002] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2024-03-21 22:44:39,003] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2024-03-21 22:44:39,003] [INFO] [config.py:1063:print]   world_size ................... 1
# [2024-03-21 22:44:39,003] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2024-03-21 22:44:39,003] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 0,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 5.000000e+07,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+07,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": null,
#     "offload_optimizer": null,
#     "sub_group_size": 1.000000e+09,
#     "prefetch_bucket_size": 5.000000e+07,
#     "param_persistence_threshold": 1.000000e+05,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": false,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2024-03-21 22:44:39,009] [INFO] [config.py:1063:print]   zero_enabled ................. False
# [2024-03-21 22:44:39,009] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 0
# [2024-03-21 22:44:39,010] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 16,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 0,
#         "allgather_partitions": true,
#         "reduce_scatter": true,
#         "allgather_bucket_size": 5.000000e+07,
#         "reduce_bucket_size": 5.000000e+07,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "cpu_offload": false
#     }
# }
# Loading extension module fused_adam...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py38_cu118/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -isystem /usr/local/lib/python3.8/dist-packages/torch/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.8/dist-packages/torch/include/THC -isystem /usr/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -fPIC -std=c++14 -c /usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/usr/local/lib/python3.8/dist-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Time to load utils op: 13.526972532272339 seconds
# Loading extension module utils...

# %%
# Train the CNN with DeepSpeed
for epoch in range(epochs): 
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)
        if fp16:
            inputs = inputs.half()        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model_engine(inputs)             # Changed net_cnn to model_engine
        loss = criterion(outputs, labels)
        
        # Backward pass
        model_engine.backward(loss)                # Changed net_cnn to model_engine
        model_engine.step()                        # Changed net_cnn to model_engine
        
        # print the loss and accuracy metrics log_interval mini-batches
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        if i % log_interval == (log_interval - 1):  
            print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / log_interval, 100.*correct/total))
            writer_ds.add_scalar("Training Cross Entropy Loss", running_loss / log_interval, i + 1)
            writer_ds.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
            running_loss = 0.0
            
    # print the last iterations 
    print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / ((i % log_interval) + 1), 100.*correct/total))
    writer.add_scalar("Training Cross Entropy Loss", running_loss / ((i % log_interval) + 1), i + 1)
    writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
    
print('Training Done')
writer_ds.add_graph(model_engine, inputs)
writer_ds.flush()
writer_ds.close()
# Out:
# [epoch 0, iterations   100] loss: 2.110 accuracy: 22.031250 %
# [epoch 0, iterations   200] loss: 1.875 accuracy: 27.085938 %
# [epoch 0, iterations   300] loss: 1.758 accuracy: 30.229167 %
# [epoch 0, iterations   400] loss: 1.677 accuracy: 32.171875 %
# [epoch 0, iterations   500] loss: 1.591 accuracy: 34.209375 %
# [2024-03-21 22:51:52,165] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 22:51:52,165] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 32768 to 65536
# [2024-03-21 22:51:52,170] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 501
# [2024-03-21 22:51:52,171] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 65536 to 32768.0
# [2024-03-21 22:51:52,171] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 65536, reducing to 32768.0
# [epoch 0, iterations   600] loss: 1.565 accuracy: 35.643229 %
# [2024-03-21 22:51:52,766] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 608
# [2024-03-21 22:51:52,766] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768.0 to 16384.0
# [2024-03-21 22:51:52,767] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 32768.0, reducing to 16384.0
# [epoch 0, iterations   700] loss: 1.542 accuracy: 36.868304 %
# [epoch 0, iterations   782] loss: 1.510 accuracy: 37.684000 %
# [epoch 1, iterations   100] loss: 1.452 accuracy: 46.359375 %
# [epoch 1, iterations   200] loss: 1.456 accuracy: 46.906250 %
# [epoch 1, iterations   300] loss: 1.446 accuracy: 46.937500 %
# [2024-03-21 22:51:55,713] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 22:51:55,714] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 16384.0 to 32768.0
# [epoch 1, iterations   400] loss: 1.426 accuracy: 47.417969 %
# [epoch 1, iterations   500] loss: 1.391 accuracy: 47.918750 %
# [epoch 1, iterations   600] loss: 1.357 accuracy: 48.460938 %
# [epoch 1, iterations   700] loss: 1.359 accuracy: 48.866071 %
# [epoch 1, iterations   782] loss: 1.343 accuracy: 49.196000 %
# Training Done

# %% [markdown]
# The previous steps are aggregated into the python script [cifar10_deepspeed.py](./code/moe/cifar10_deepspeed.py).

# %% [markdown]
# ## 6.2.2 Scale-out training with Data Parallelism
#
# Let's now scale our previous training using distributed training techniques. To run the previous code on 4 GPUs using Data Parallel Distribution, instead of using `torch.distributed.launch` or `torchrun` commands, we can use DeepSpeed implementation.
#
# Old: `python -m torch.distributed.launch --nproc_per_node=4 my_code.py <args>`
#
# With DeepSpeed, simply replace `torch.distributed.launch` with `deepspeed` and add a new argument `--deepspeed ds_config.json`
#
# `deepspeed --num_gpus=4 my_code.py  <args> --deepspeed ds_config.json`
#
# Execute the next cell to run the previous `cifar10_deepspeed.py` training code on 4 GPUs with DeepSpeed:

# %%
# Kill zombie processes
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
# disable P2P connections for single-node DeepSpeed runs
# %env NCCL_P2P_DISABLE=1

# run the training on 4 GPUs with Data parallel
# !deepspeed --num_gpus=4 /dli/code/moe/cifar10_deepspeed.py \
    --deepspeed \
    --deepspeed_config /dli/code/moe/ds_config.json \
    --profile-execution=True \
    --profile-name='zero0'
# Out:
# env: NCCL_P2P_DISABLE=1
# [2024-03-21 23:04:14,004] [WARNING] [runner.py:159:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2024-03-21 23:04:14,053] [INFO] [runner.py:457:main] cmd = /usr/bin/python -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMSwgMiwgM119 --master_addr=127.0.0.1 --master_port=29500 /dli/code/moe/cifar10_deepspeed.py --deepspeed --deepspeed_config /dli/code/moe/ds_config.json --profile-execution=True --profile-name=zero0
# [2024-03-21 23:04:15,812] [INFO] [launch.py:96:main] 0 NCCL_P2P_DISABLE=1
# [2024-03-21 23:04:15,812] [INFO] [launch.py:96:main] 0 NCCL_VERSION=2.15.5
# [2024-03-21 23:04:15,812] [INFO] [launch.py:103:main] WORLD INFO DICT: {'localhost': [0, 1, 2, 3]}
# [2024-03-21 23:04:15,812] [INFO] [launch.py:109:main] nnodes=1, num_local_procs=4, node_rank=0
# [2024-03-21 23:04:15,812] [INFO] [launch.py:122:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1, 2, 3]})
# [2024-03-21 23:04:15,812] [INFO] [launch.py:123:main] dist_world_size=4
# [2024-03-21 23:04:15,812] [INFO] [launch.py:125:main] Setting CUDA_VISIBLE_DEVICES=0,1,2,3
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# [2024-03-21 23:04:19,451] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-21 23:04:19,451] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2024-03-21 23:04:19,562] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-21 23:04:19,627] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-21 23:04:19,646] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# [2024-03-21 23:04:22,093] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10126781463623047 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10236477851867676 seconds
# [2024-03-21 23:04:22,855] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# [2024-03-21 23:04:22,855] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = FusedAdam
# [2024-03-21 23:04:22,855] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 optimizer with dynamic loss scale
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10230350494384766 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.24690628051757812 seconds
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# [2024-03-21 23:04:23,459] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2024-03-21 23:04:23,459] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2024-03-21 23:04:23,459] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7f42ae5f15e0>
# [2024-03-21 23:04:23,459] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2024-03-21 23:04:23,459] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   amp_params ................... False
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2024-03-21 23:04:23,460] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   dump_state ................... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...[2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
#
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   pld_params ................... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2024-03-21 23:04:23,461] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   train_batch_size ............. 16
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  4
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   world_size ................... 4
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 0,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 5.000000e+07,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+07,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": null,
#     "offload_optimizer": null,
#     "sub_group_size": 1.000000e+09,
#     "prefetch_bucket_size": 5.000000e+07,
#     "param_persistence_threshold": 1.000000e+05,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": false,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   zero_enabled ................. False
# [2024-03-21 23:04:23,462] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 0
# [2024-03-21 23:04:23,462] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 16,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 0,
#         "allgather_partitions": true,
#         "reduce_scatter": true,
#         "allgather_bucket_size": 5.000000e+07,
#         "reduce_bucket_size": 5.000000e+07,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "cpu_offload": false
#     }
# }
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.09632420539855957 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10193324089050293 seconds
# Loading extension module utils...
# Time to load utils op: 0.10233163833618164 seconds
# Time to load utils op: 0.10223531723022461 seconds
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# [W kineto_shim.cpp:330] Profiler is not initialized: skipping step() invocation
# STAGE:2024-03-21 23:04:24 9406:9406 ActivityProfilerController.cpp:294] Completed Stage: Warm Up
# STAGE:2024-03-21 23:04:24 9406:9406 ActivityProfilerController.cpp:300] Completed Stage: Collection
# STAGE:2024-03-21 23:04:24 9406:9406 output_json.cpp:417] Completed Stage: Post Processing
# [2024-03-21 23:04:24,624] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 93
# [2024-03-21 23:04:24,624] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 93
# [2024-03-21 23:04:24,624] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2024-03-21 23:04:24,624] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 93
# [2024-03-21 23:04:24,624] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2024-03-21 23:04:24,624] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2024-03-21 23:04:24,625] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 93
# [2024-03-21 23:04:24,625] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2024-03-21 23:04:24,625] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 32768, reducing to 16384.0
# [epoch 0, iterations   100] loss: 2.242 accuracy: 15.000000 %
# [epoch 0, iterations   100] loss: 2.215 accuracy: 14.750000 %
# [epoch 0, iterations   100] loss: 2.226 accuracy: 14.000000 %
# [epoch 0, iterations   100] loss: 2.252 accuracy: 17.000000 %
# [2024-03-21 23:04:24,767] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 126
# [2024-03-21 23:04:24,767] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2024-03-21 23:04:24,767] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 126
# [2024-03-21 23:04:24,767] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 126
# [2024-03-21 23:04:24,767] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2024-03-21 23:04:24,767] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2024-03-21 23:04:24,768] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 126
# [2024-03-21 23:04:24,768] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2024-03-21 23:04:24,768] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 16384.0, reducing to 8192.0
# [epoch 0, iterations   200] loss: 1.999 accuracy: 20.375000 %
# [epoch 0, iterations   200] loss: 2.077 accuracy: 18.250000 %[epoch 0, iterations   200] loss: 1.993 accuracy: 19.250000 %
#
# [epoch 0, iterations   200] loss: 1.995 accuracy: 20.875000 %
# [epoch 0, iterations   300] loss: 1.937 accuracy: 23.583333 %[epoch 0, iterations   300] loss: 1.923 accuracy: 20.833333 %
#
# [epoch 0, iterations   300] loss: 1.955 accuracy: 22.166667 %
# [epoch 0, iterations   300] loss: 1.885 accuracy: 23.000000 %
# [epoch 0, iterations   400] loss: 1.797 accuracy: 24.375000 %[epoch 0, iterations   400] loss: 1.804 accuracy: 25.812500 %[epoch 0, iterations   400] loss: 1.822 accuracy: 25.125000 %
#
#
# [epoch 0, iterations   400] loss: 1.873 accuracy: 25.062500 %
# [epoch 0, iterations   500] loss: 1.699 accuracy: 27.400000 %
# [epoch 0, iterations   500] loss: 1.801 accuracy: 25.600000 %
# [epoch 0, iterations   500] loss: 1.784 accuracy: 27.750000 %
# [epoch 0, iterations   500] loss: 1.736 accuracy: 26.950000 %
# [epoch 0, iterations   600] loss: 1.728 accuracy: 29.458333 %
# [epoch 0, iterations   600] loss: 1.685 accuracy: 28.916667 %
# [epoch 0, iterations   600] loss: 1.745 accuracy: 26.916667 %
# [epoch 0, iterations   600] loss: 1.684 accuracy: 28.791667 %
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 624
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 624
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 624
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 624
# [2024-03-21 23:04:26,901] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:26,901] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations   700] loss: 1.656 accuracy: 31.035714 %[epoch 0, iterations   700] loss: 1.720 accuracy: 30.535714 %[epoch 0, iterations   700] loss: 1.724 accuracy: 28.285714 %
#
#
# [epoch 0, iterations   700] loss: 1.772 accuracy: 29.750000 %
# [epoch 0, iterations   800] loss: 1.734 accuracy: 31.437500 %
# [epoch 0, iterations   800] loss: 1.652 accuracy: 30.031250 %
# [epoch 0, iterations   800] loss: 1.588 accuracy: 32.031250 %
# [epoch 0, iterations   800] loss: 1.679 accuracy: 30.625000 %
# [epoch 0, iterations   900] loss: 1.669 accuracy: 32.083333 %
# [epoch 0, iterations   900] loss: 1.624 accuracy: 33.055556 %[epoch 0, iterations   900] loss: 1.673 accuracy: 30.722222 %
#
# [epoch 0, iterations   900] loss: 1.697 accuracy: 31.444444 %
# [epoch 0, iterations  1000] loss: 1.611 accuracy: 32.875000 %[epoch 0, iterations  1000] loss: 1.662 accuracy: 31.775000 %
#
# [epoch 0, iterations  1000] loss: 1.648 accuracy: 33.700000 %
# [epoch 0, iterations  1000] loss: 1.595 accuracy: 32.500000 %
# [epoch 0, iterations  1100] loss: 1.624 accuracy: 33.704545 %[epoch 0, iterations  1100] loss: 1.577 accuracy: 32.750000 %
#
# [epoch 0, iterations  1100] loss: 1.589 accuracy: 34.272727 %
# [epoch 0, iterations  1100] loss: 1.559 accuracy: 33.431818 %
# [2024-03-21 23:04:29,052] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:29,052] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:29,052] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:29,052] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:29,052] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:29,052] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:29,053] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:29,053] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:29,064] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1128
# [2024-03-21 23:04:29,064] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1128
# [2024-03-21 23:04:29,065] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1128
# [2024-03-21 23:04:29,065] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:29,065] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:29,065] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:29,065] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1128
# [2024-03-21 23:04:29,065] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:29,065] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations  1200] loss: 1.690 accuracy: 34.166667 %
# [epoch 0, iterations  1200] loss: 1.541 accuracy: 33.645833 %
# [epoch 0, iterations  1200] loss: 1.543 accuracy: 34.895833 %
# [epoch 0, iterations  1200] loss: 1.539 accuracy: 34.250000 %
# [epoch 0, iterations  1300] loss: 1.579 accuracy: 34.942308 %[epoch 0, iterations  1300] loss: 1.665 accuracy: 34.038462 %
# [epoch 0, iterations  1300] loss: 1.499 accuracy: 35.576923 %
#
# [epoch 0, iterations  1300] loss: 1.610 accuracy: 34.538462 %
# [epoch 0, iterations  1400] loss: 1.583 accuracy: 35.232143 %
# [epoch 0, iterations  1400] loss: 1.644 accuracy: 34.464286 %
# [epoch 0, iterations  1400] loss: 1.614 accuracy: 35.875000 %
# [epoch 0, iterations  1400] loss: 1.607 accuracy: 35.089286 %
# [epoch 0, iterations  1500] loss: 1.578 accuracy: 36.216667 %
# [epoch 0, iterations  1500] loss: 1.609 accuracy: 35.833333 %
# [epoch 0, iterations  1500] loss: 1.577 accuracy: 34.916667 %
# [epoch 0, iterations  1500] loss: 1.574 accuracy: 35.566667 %
# [epoch 0, iterations  1600] loss: 1.608 accuracy: 35.187500 %[epoch 0, iterations  1600] loss: 1.560 accuracy: 36.156250 %
#
# [epoch 0, iterations  1600] loss: 1.515 accuracy: 36.765625 %
# [epoch 0, iterations  1600] loss: 1.511 accuracy: 36.203125 %
# [2024-03-21 23:04:31,187] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:31,187] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:31,187] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:31,187] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:31,187] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:31,187] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:31,188] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:31,188] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:31,412] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1682
# [2024-03-21 23:04:31,412] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1682
# [2024-03-21 23:04:31,412] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1682
# [2024-03-21 23:04:31,412] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:31,412] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:31,412] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:31,413] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1682
# [2024-03-21 23:04:31,413] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:31,413] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations  1700] loss: 1.482 accuracy: 35.647059 %
# [epoch 0, iterations  1700] loss: 1.610 accuracy: 36.352941 %[epoch 0, iterations  1700] loss: 1.552 accuracy: 37.323529 %
#
# [epoch 0, iterations  1700] loss: 1.577 accuracy: 36.529412 %
# [epoch 0, iterations  1800] loss: 1.521 accuracy: 36.180556 %[epoch 0, iterations  1800] loss: 1.495 accuracy: 36.930556 %
#
# [epoch 0, iterations  1800] loss: 1.516 accuracy: 37.652778 %
# [epoch 0, iterations  1800] loss: 1.549 accuracy: 36.944444 %
# [epoch 0, iterations  1900] loss: 1.541 accuracy: 37.263158 %
# [epoch 0, iterations  1900] loss: 1.498 accuracy: 38.157895 %[epoch 0, iterations  1900] loss: 1.425 accuracy: 36.894737 %
#
# [epoch 0, iterations  1900] loss: 1.555 accuracy: 37.250000 %
# [epoch 0, iterations  2000] loss: 1.520 accuracy: 38.575000 %
# [epoch 0, iterations  2000] loss: 1.490 accuracy: 37.700000 %[epoch 0, iterations  2000] loss: 1.491 accuracy: 37.262500 %
#
# [2024-03-21 23:04:32,763] [INFO] [logging.py:69:log_dist] [Rank 0] step=2000, skipped=5, lr=[0.001], mom=[[0.8, 0.999]]
# [2024-03-21 23:04:32,763] [INFO] [timer.py:193:stop] 0/2000, SamplesPerSec=3966.561363017747, MemAllocated=0.01GB, MaxMemAllocated=0.01GB
# [epoch 0, iterations  2000] loss: 1.576 accuracy: 37.450000 %
# [epoch 0, iterations  2100] loss: 1.464 accuracy: 38.238095 %
# [epoch 0, iterations  2100] loss: 1.433 accuracy: 37.654762 %[epoch 0, iterations  2100] loss: 1.478 accuracy: 38.880952 %
#
# [epoch 0, iterations  2100] loss: 1.578 accuracy: 37.702381 %
# [2024-03-21 23:04:33,543] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:33,543] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:33,543] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:33,543] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:33,543] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:33,543] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:33,544] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:33,544] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 0, iterations  2200] loss: 1.454 accuracy: 39.306818 %
# [epoch 0, iterations  2200] loss: 1.495 accuracy: 38.613636 %
# [epoch 0, iterations  2200] loss: 1.605 accuracy: 37.909091 %
# [epoch 0, iterations  2200] loss: 1.447 accuracy: 38.204545 %
# [epoch 0, iterations  2300] loss: 1.484 accuracy: 39.652174 %
# [epoch 0, iterations  2300] loss: 1.457 accuracy: 39.086957 %
# [epoch 0, iterations  2300] loss: 1.430 accuracy: 38.282609 %
# [epoch 0, iterations  2300] loss: 1.346 accuracy: 38.815217 %
# [2024-03-21 23:04:34,298] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2359
# [2024-03-21 23:04:34,298] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:34,298] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2359
# [2024-03-21 23:04:34,298] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2359
# [2024-03-21 23:04:34,298] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:34,299] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:34,299] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2359
# [2024-03-21 23:04:34,299] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:34,299] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations  2400] loss: 1.428 accuracy: 39.541667 %[epoch 0, iterations  2400] loss: 1.348 accuracy: 40.135417 %
#
# [epoch 0, iterations  2400] loss: 1.426 accuracy: 38.750000 %
# [epoch 0, iterations  2400] loss: 1.466 accuracy: 39.197917 %
# [epoch 0, iterations  2500] loss: 1.384 accuracy: 40.090000 %
# [epoch 0, iterations  2500] loss: 1.429 accuracy: 40.500000 %[epoch 0, iterations  2500] loss: 1.436 accuracy: 39.110000 %
#
# [epoch 0, iterations  2500] loss: 1.380 accuracy: 39.570000 %
# [epoch 0, iterations  2600] loss: 1.384 accuracy: 40.355769 %
# [epoch 0, iterations  2600] loss: 1.407 accuracy: 39.384615 %[epoch 0, iterations  2600] loss: 1.394 accuracy: 40.903846 %
#
# [epoch 0, iterations  2600] loss: 1.483 accuracy: 39.778846 %
# [epoch 0, iterations  2700] loss: 1.448 accuracy: 40.629630 %
# [epoch 0, iterations  2700] loss: 1.417 accuracy: 41.092593 %[epoch 0, iterations  2700] loss: 1.405 accuracy: 39.814815 %
#
# [epoch 0, iterations  2700] loss: 1.506 accuracy: 40.018519 %
# [epoch 0, iterations  2800] loss: 1.393 accuracy: 40.883929 %
# [epoch 0, iterations  2800] loss: 1.390 accuracy: 40.142857 %[epoch 0, iterations  2800] loss: 1.374 accuracy: 41.491071 %
#
# [epoch 0, iterations  2800] loss: 1.469 accuracy: 40.303571 %
# [2024-03-21 23:04:36,448] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:36,448] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:36,448] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:36,448] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:36,448] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:36,448] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:36,448] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:36,449] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:36,564] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2887
# [2024-03-21 23:04:36,564] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2887
# [2024-03-21 23:04:36,564] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2887
# [2024-03-21 23:04:36,564] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:36,564] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:36,564] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:36,565] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2887
# [2024-03-21 23:04:36,565] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:36,565] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations  2900] loss: 1.380 accuracy: 41.715517 %
# [epoch 0, iterations  2900] loss: 1.366 accuracy: 41.284483 %
# [epoch 0, iterations  2900] loss: 1.438 accuracy: 40.413793 %
# [epoch 0, iterations  2900] loss: 1.531 accuracy: 40.534483 %
# [epoch 0, iterations  3000] loss: 1.385 accuracy: 41.666667 %
# [epoch 0, iterations  3000] loss: 1.382 accuracy: 40.700000 %[epoch 0, iterations  3000] loss: 1.326 accuracy: 42.016667 %
#
# [epoch 0, iterations  3000] loss: 1.478 accuracy: 40.675000 %
# [epoch 0, iterations  3100] loss: 1.419 accuracy: 42.250000 %
# [epoch 0, iterations  3100] loss: 1.391 accuracy: 41.951613 %
# [epoch 0, iterations  3100] loss: 1.461 accuracy: 41.024194 %
# [epoch 0, iterations  3100] loss: 1.417 accuracy: 40.943548 %
# [epoch 1, iterations   100] loss: 1.350 accuracy: 54.500000 %[epoch 1, iterations   100] loss: 1.414 accuracy: 45.000000 %[epoch 1, iterations   100] loss: 1.263 accuracy: 55.500000 %
#
#
# [epoch 1, iterations   100] loss: 1.375 accuracy: 51.750000 %
# [epoch 1, iterations   200] loss: 1.426 accuracy: 50.500000 %[epoch 1, iterations   200] loss: 1.340 accuracy: 47.625000 %
#
# [epoch 1, iterations   200] loss: 1.432 accuracy: 52.125000 %
# [epoch 1, iterations   200] loss: 1.346 accuracy: 51.250000 %
# [2024-03-21 23:04:38,876] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:38,876] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:38,876] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:38,876] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:38,876] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:38,876] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:38,877] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:38,877] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:38,951] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3405
# [2024-03-21 23:04:38,951] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3405
# [2024-03-21 23:04:38,951] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3405
# [2024-03-21 23:04:38,951] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:38,951] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:38,951] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:38,952] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3405
# [2024-03-21 23:04:38,952] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:38,952] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations   300] loss: 1.428 accuracy: 49.416667 %
# [epoch 1, iterations   300] loss: 1.403 accuracy: 48.500000 %
# [epoch 1, iterations   300] loss: 1.334 accuracy: 52.500000 %
# [epoch 1, iterations   300] loss: 1.336 accuracy: 50.333333 %
# [epoch 1, iterations   400] loss: 1.313 accuracy: 49.250000 %[epoch 1, iterations   400] loss: 1.321 accuracy: 49.000000 %
# [epoch 1, iterations   400] loss: 1.329 accuracy: 52.250000 %
#
# [epoch 1, iterations   400] loss: 1.399 accuracy: 49.500000 %
# [epoch 1, iterations   500] loss: 1.229 accuracy: 50.300000 %
# [epoch 1, iterations   500] loss: 1.393 accuracy: 49.400000 %
# [epoch 1, iterations   500] loss: 1.389 accuracy: 51.550000 %
# [epoch 1, iterations   500] loss: 1.284 accuracy: 50.250000 %
# [epoch 1, iterations   600] loss: 1.280 accuracy: 51.000000 %
# [epoch 1, iterations   600] loss: 1.365 accuracy: 49.791667 %[epoch 1, iterations   600] loss: 1.387 accuracy: 51.916667 %
#
# [epoch 1, iterations   600] loss: 1.340 accuracy: 50.625000 %
# [epoch 1, iterations   700] loss: 1.258 accuracy: 51.642857 %
# [epoch 1, iterations   700] loss: 1.286 accuracy: 49.821429 %[epoch 1, iterations   700] loss: 1.326 accuracy: 51.964286 %
#
# [epoch 1, iterations   700] loss: 1.380 accuracy: 50.500000 %
# [2024-03-21 23:04:41,122] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:41,122] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:41,122] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:41,122] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:41,122] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:41,122] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:41,123] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:41,123] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 1, iterations   800] loss: 1.392 accuracy: 51.093750 %
# [epoch 1, iterations   800] loss: 1.257 accuracy: 50.843750 %
# [epoch 1, iterations   800] loss: 1.263 accuracy: 52.718750 %
# [epoch 1, iterations   800] loss: 1.314 accuracy: 50.843750 %
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3937
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3937
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3937
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3937
# [2024-03-21 23:04:41,258] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:41,258] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [2024-03-21 23:04:41,531] [INFO] [logging.py:69:log_dist] [Rank 0] step=4000, skipped=9, lr=[0.001], mom=[[0.8, 0.999]]
# [2024-03-21 23:04:41,532] [INFO] [timer.py:193:stop] 0/4000, SamplesPerSec=3938.439296511968, MemAllocated=0.01GB, MaxMemAllocated=0.01GB
# [epoch 1, iterations   900] loss: 1.327 accuracy: 51.027778 %
# [epoch 1, iterations   900] loss: 1.305 accuracy: 51.222222 %[epoch 1, iterations   900] loss: 1.344 accuracy: 52.750000 %
#
# [epoch 1, iterations   900] loss: 1.387 accuracy: 51.111111 %
# [epoch 1, iterations  1000] loss: 1.304 accuracy: 51.275000 %
# [epoch 1, iterations  1000] loss: 1.329 accuracy: 51.200000 %
# [epoch 1, iterations  1000] loss: 1.329 accuracy: 52.875000 %
# [epoch 1, iterations  1000] loss: 1.271 accuracy: 51.425000 %
# [epoch 1, iterations  1100] loss: 1.330 accuracy: 51.545455 %
# [epoch 1, iterations  1100] loss: 1.275 accuracy: 51.340909 %
# [epoch 1, iterations  1100] loss: 1.200 accuracy: 53.090909 %
# [epoch 1, iterations  1100] loss: 1.250 accuracy: 51.750000 %
# [epoch 1, iterations  1200] loss: 1.402 accuracy: 51.229167 %
# [epoch 1, iterations  1200] loss: 1.233 accuracy: 51.812500 %
# [epoch 1, iterations  1200] loss: 1.270 accuracy: 53.208333 %
# [epoch 1, iterations  1200] loss: 1.246 accuracy: 51.937500 %
# [epoch 1, iterations  1300] loss: 1.304 accuracy: 51.634615 %
# [epoch 1, iterations  1300] loss: 1.183 accuracy: 51.865385 %
# [epoch 1, iterations  1300] loss: 1.429 accuracy: 52.903846 %
# [epoch 1, iterations  1300] loss: 1.259 accuracy: 52.211538 %
# [2024-03-21 23:04:43,465] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:43,465] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:43,465] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:43,465] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:43,465] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:43,465] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:43,466] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:43,466] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4493
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4493
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4493
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4493
# [2024-03-21 23:04:43,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:43,705] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations  1400] loss: 1.359 accuracy: 51.750000 %[epoch 1, iterations  1400] loss: 1.279 accuracy: 52.017857 %
#
# [epoch 1, iterations  1400] loss: 1.366 accuracy: 52.857143 %
# [epoch 1, iterations  1400] loss: 1.356 accuracy: 52.321429 %
# [epoch 1, iterations  1500] loss: 1.310 accuracy: 51.950000 %
# [epoch 1, iterations  1500] loss: 1.261 accuracy: 52.400000 %
# [epoch 1, iterations  1500] loss: 1.306 accuracy: 52.933333 %
# [epoch 1, iterations  1500] loss: 1.327 accuracy: 52.300000 %
# [epoch 1, iterations  1600] loss: 1.289 accuracy: 51.968750 %[epoch 1, iterations  1600] loss: 1.160 accuracy: 52.703125 %
#
# [epoch 1, iterations  1600] loss: 1.365 accuracy: 52.750000 %
# [epoch 1, iterations  1600] loss: 1.291 accuracy: 52.390625 %
# [epoch 1, iterations  1700] loss: 1.374 accuracy: 51.852941 %[epoch 1, iterations  1700] loss: 1.235 accuracy: 52.852941 %
# [epoch 1, iterations  1700] loss: 1.180 accuracy: 53.014706 %
#
# [epoch 1, iterations  1700] loss: 1.321 accuracy: 52.367647 %
# [epoch 1, iterations  1800] loss: 1.224 accuracy: 53.125000 %
# [epoch 1, iterations  1800] loss: 1.234 accuracy: 52.208333 %
# [epoch 1, iterations  1800] loss: 1.281 accuracy: 53.069444 %
# [epoch 1, iterations  1800] loss: 1.273 accuracy: 52.569444 %
# [2024-03-21 23:04:45,914] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:45,914] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:45,914] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:45,914] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:45,914] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:45,914] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:45,915] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:45,915] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:46,009] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5015
# [2024-03-21 23:04:46,009] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5015
# [2024-03-21 23:04:46,009] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5015
# [2024-03-21 23:04:46,009] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:46,009] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:46,009] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:46,010] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5015
# [2024-03-21 23:04:46,010] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:46,010] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations  1900] loss: 1.264 accuracy: 52.328947 %
# [epoch 1, iterations  1900] loss: 1.237 accuracy: 53.289474 %[epoch 1, iterations  1900] loss: 1.111 accuracy: 53.539474 %
#
# [epoch 1, iterations  1900] loss: 1.236 accuracy: 52.671053 %
# [epoch 1, iterations  2000] loss: 1.251 accuracy: 52.637500 %[epoch 1, iterations  2000] loss: 1.245 accuracy: 53.587500 %[epoch 1, iterations  2000] loss: 1.254 accuracy: 53.425000 %
#
#
# [epoch 1, iterations  2000] loss: 1.315 accuracy: 52.762500 %
# [epoch 1, iterations  2100] loss: 1.180 accuracy: 53.583333 %[epoch 1, iterations  2100] loss: 1.236 accuracy: 52.761905 %
#
# [epoch 1, iterations  2100] loss: 1.194 accuracy: 53.654762 %
# [epoch 1, iterations  2100] loss: 1.381 accuracy: 52.559524 %
# [epoch 1, iterations  2200] loss: 1.158 accuracy: 53.965909 %[epoch 1, iterations  2200] loss: 1.262 accuracy: 52.863636 %[epoch 1, iterations  2200] loss: 1.354 accuracy: 53.443182 %
#
#
# [epoch 1, iterations  2200] loss: 1.193 accuracy: 52.704545 %
# [epoch 1, iterations  2300] loss: 1.253 accuracy: 52.956522 %[epoch 1, iterations  2300] loss: 1.273 accuracy: 54.010870 %
#
# [epoch 1, iterations  2300] loss: 1.194 accuracy: 53.717391 %
# [epoch 1, iterations  2300] loss: 1.129 accuracy: 53.032609 %
# [2024-03-21 23:04:48,244] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:48,244] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:48,244] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:48,244] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:48,244] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:48,244] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:48,245] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:48,245] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 1, iterations  2400] loss: 1.109 accuracy: 54.302083 %[epoch 1, iterations  2400] loss: 1.208 accuracy: 53.041667 %
# [epoch 1, iterations  2400] loss: 1.224 accuracy: 53.812500 %
#
# [epoch 1, iterations  2400] loss: 1.212 accuracy: 53.083333 %
# [2024-03-21 23:04:48,319] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5533
# [2024-03-21 23:04:48,319] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5533
# [2024-03-21 23:04:48,319] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5533
# [2024-03-21 23:04:48,319] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:48,319] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:48,320] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:48,320] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5533
# [2024-03-21 23:04:48,320] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:48,320] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations  2500] loss: 1.235 accuracy: 54.390000 %
# [epoch 1, iterations  2500] loss: 1.249 accuracy: 53.880000 %
# [epoch 1, iterations  2500] loss: 1.142 accuracy: 53.370000 %
# [epoch 1, iterations  2500] loss: 1.173 accuracy: 53.180000 %
# [epoch 1, iterations  2600] loss: 1.179 accuracy: 54.625000 %[epoch 1, iterations  2600] loss: 1.239 accuracy: 53.451923 %
#
# [epoch 1, iterations  2600] loss: 1.191 accuracy: 53.894231 %
# [epoch 1, iterations  2600] loss: 1.240 accuracy: 53.432692 %
# [epoch 1, iterations  2700] loss: 1.252 accuracy: 53.481481 %
# [epoch 1, iterations  2700] loss: 1.217 accuracy: 54.750000 %
# [epoch 1, iterations  2700] loss: 1.206 accuracy: 54.046296 %
# [epoch 1, iterations  2700] loss: 1.259 accuracy: 53.444444 %
# [epoch 1, iterations  2800] loss: 1.158 accuracy: 53.625000 %
# [epoch 1, iterations  2800] loss: 1.195 accuracy: 54.937500 %
# [epoch 1, iterations  2800] loss: 1.196 accuracy: 54.098214 %
# [epoch 1, iterations  2800] loss: 1.248 accuracy: 53.544643 %
# [2024-03-21 23:04:50,372] [INFO] [logging.py:69:log_dist] [Rank 0] step=6000, skipped=12, lr=[0.001], mom=[[0.8, 0.999]]
# [2024-03-21 23:04:50,372] [INFO] [timer.py:193:stop] 0/6000, SamplesPerSec=3902.279865964117, MemAllocated=0.01GB, MaxMemAllocated=0.01GB
# [epoch 1, iterations  2900] loss: 1.206 accuracy: 53.793103 %[epoch 1, iterations  2900] loss: 1.185 accuracy: 55.051724 %
#
# [epoch 1, iterations  2900] loss: 1.236 accuracy: 54.112069 %
# [epoch 1, iterations  2900] loss: 1.366 accuracy: 53.586207 %
# [2024-03-21 23:04:50,525] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:50,525] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:50,525] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:50,525] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:50,525] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:50,526] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:50,526] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2024-03-21 23:04:50,526] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2024-03-21 23:04:50,588] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6048
# [2024-03-21 23:04:50,588] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6048
# [2024-03-21 23:04:50,588] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:50,588] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:50,588] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6048
# [2024-03-21 23:04:50,588] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:50,589] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6048
# [2024-03-21 23:04:50,589] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2024-03-21 23:04:50,589] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations  3000] loss: 1.173 accuracy: 54.058333 %[epoch 1, iterations  3000] loss: 1.113 accuracy: 55.225000 %
#
# [epoch 1, iterations  3000] loss: 1.189 accuracy: 54.258333 %
# [epoch 1, iterations  3000] loss: 1.322 accuracy: 53.525000 %
# [epoch 1, iterations  3100] loss: 1.247 accuracy: 55.193548 %[epoch 1, iterations  3100] loss: 1.195 accuracy: 54.145161 %
#
# [epoch 1, iterations  3100] loss: 1.271 accuracy: 54.354839 %
# [epoch 1, iterations  3100] loss: 1.246 accuracy: 53.604839 %
# Training Done
# Training Done
# Training Done
# Training Done
# Accuracy of the network on the 10000 test images: 56.180000 %
# Accuracy of plane : 70.300000 %
# Accuracy of   car : 75.300000 %
# Accuracy of  bird : 44.300000 %
# Accuracy of   cat : 32.200000 %
# Accuracy of  deer : 45.300000 %
# Accuracy of   dog : 38.800000 %
# Accuracy of  frog : 60.300000 %
# Accuracy of horse : 74.500000 %
# Accuracy of  ship : 76.300000 %
# Accuracy of truck : 44.500000 %
# Evaluation Done
# Accuracy of the network on the 10000 test images: 56.180000 %
# Accuracy of plane : 70.300000 %
# Accuracy of   car : 75.300000 %
# Accuracy of  bird : 44.300000 %
# Accuracy of   cat : 32.200000 %
# Accuracy of  deer : 45.300000 %
# Accuracy of   dog : 38.800000 %
# Accuracy of  frog : 60.300000 %
# Accuracy of horse : 74.500000 %
# Accuracy of  ship : 76.300000 %
# Accuracy of truck : 44.500000 %
# Evaluation Done
# Accuracy of the network on the 10000 test images: 56.180000 %
# Accuracy of plane : 70.300000 %
# Accuracy of   car : 75.300000 %
# Accuracy of  bird : 44.300000 %
# Accuracy of   cat : 32.200000 %
# Accuracy of  deer : 45.300000 %
# Accuracy of   dog : 38.800000 %
# Accuracy of  frog : 60.300000 %
# Accuracy of horse : 74.500000 %
# Accuracy of  ship : 76.300000 %
# Accuracy of truck : 44.500000 %
# Evaluation Done
# Accuracy of the network on the 10000 test images: 56.180000 %
# Accuracy of plane : 70.300000 %
# Accuracy of   car : 75.300000 %
# Accuracy of  bird : 44.300000 %
# Accuracy of   cat : 32.200000 %
# Accuracy of  deer : 45.300000 %
# Accuracy of   dog : 38.800000 %
# Accuracy of  frog : 60.300000 %
# Accuracy of horse : 74.500000 %
# Accuracy of  ship : 76.300000 %
# Accuracy of truck : 44.500000 %
# Evaluation Done
# [2024-03-21 23:04:56,897] [INFO] [launch.py:210:main] Process 9409 exits successfully.
# [2024-03-21 23:04:56,897] [INFO] [launch.py:210:main] Process 9408 exits successfully.
# [2024-03-21 23:04:56,897] [INFO] [launch.py:210:main] Process 9407 exits successfully.
# [2024-03-21 23:04:57,898] [INFO] [launch.py:210:main] Process 9406 exits successfully.

# %% [markdown]
# To execute the same run on a SLURM based cluster, simply write the SBATCH script allocating the desired resources and invoke the same DeepSpeed command.
#
# Run the next cell to create the SBATCH script allocating 2 nodes to run the previous training with DeepSpeed.

# %%
# %%writefile /dli/code/run_cifar10_deepspeed_2Nodes.sh
# #!/bin/bash
# #SBATCH --job-name=dli_ds
# #SBATCH --nodes=2
# #SBATCH --ntasks-per-node=1
# #SBATCH --cpus-per-task=32 ### Number of threads per task (OMP threads)
# #SBATCH -o /dli/nemo/logs/%j.out
# #SBATCH -e /dli/nemo/logs/%j.err
#
# # Number of nodes
# NUM_NODES=2
# # Number of GPUs per node
# NUM_GPUS=2
#
#
# deepspeed --num_nodes=${NUM_NODES} --hostfile /dli/code/moe/hostfile --num_gpus=${NUM_GPUS} /dli/code/moe/cifar10_deepspeed.py \
#     --deepspeed \
#     --deepspeed_config /dli/code/moe/ds_config.json \
#     --profile-execution=True \
#     --profile-name='zero0_sbatch'
# Out:
# Writing /dli/code/run_cifar10_deepspeed_2Nodes.sh

# %% [markdown]
# Now, let's submit the previous sbatch script [run_cifar10_deepspeed_2Nodes.sh](./code/run_cifar10_deepspeed_2Nodes.sh) and check the SLURM queue using the `squeue` command.

# %%
# Submit the 2 nodes jobs
# !sbatch /dli/code/run_cifar10_deepspeed_2Nodes.sh

# Check the SLURM queue
# !squeue
# Out:
# Submitted batch job 18
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#                 18  slurmpar   dli_ds     root PD       0:00      2 (None)

# %%
# Check GPU utilization on the master node
# !sleep 60
# !nvidia-smi
# Out:
# Thu Mar 21 23:09:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.12             Driver Version: 535.104.12   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  | 00000001:00:00.0 Off |                    0 |
# | N/A   38C    P0              74W / 300W |    645MiB / 81920MiB |     21%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80GB PCIe          On  | 00000002:00:00.0 Off |                    0 |
# | N/A   42C    P0              80W / 300W |    645MiB / 81920MiB |     48%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80GB PCIe          On  | 00000003:00:00.0 Off |                    0 |
# | N/A   39C    P0              77W / 300W |    645MiB / 81920MiB |     50%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80GB PCIe          On  | 00000004:00:00.0 Off |                    0 |
# | N/A   40C    P0              78W / 300W |    645MiB / 81920MiB |     47%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## 6.2.3 Zero Redundancy Optimizer
#
# [ZeRO](https://www.deepspeed.ai/tutorials/zero/) reduces the memory consumption of each GPU by distributing the model's training states (weights, gradients, and optimizer states) across the available devices. ZeRO is implemented as 3 accumulative stages:
#
# - **ZeRO-1:** The optimizer states are partitioned across the processes, so that each process updates only its partition. For instance, the Adam optimizer will store 32-bit weights, first, and second moment estimates.
# - **ZeRO-2:** In addition to Zero 1, the reduced 32-bit gradients for updating the model weights are also partitioned such that each process retains only the gradients corresponding to its portion of the optimizer states.
# - **ZeRO-3:** In addition to Zero 2, the 16-bit model parameters are partitioned across the processes. ZeRO-3 will automatically collect and partition them during the forward and backward passes. ZeRO-3 also includes the [ZeRO-Infinity](https://arxiv.org/pdf/2104.07857.pdf) engine that offloads to both CPU and NVMe memory for memory savings.
#
# ```
# {
#  "zero_optimization": {
#     "stage": [0|1|2|3],
#     "allgather_partitions": [true|false],
#     "allgather_bucket_size": 5e8,
#     "overlap_comm": false,
#     "reduce_scatter": [true|false],
#     "reduce_bucket_size": 5e8,
#     "contiguous_gradients" : [true|false],
#     "offload_param": {
#       ...
#     },
#     "offload_optimizer": {
#       ...
#     },
#     "stage3_max_live_parameters" : 1e9,
#     "stage3_max_reuse_distance" : 1e9,
#     "stage3_prefetch_bucket_size" : 5e8,
#     "stage3_param_persistence_threshold" : 1e6,
#     "sub_group_size" : 1e12,
#     "elastic_checkpoint" : [true|false],
#     "stage3_gather_16bit_weights_on_model_save": [true|false],
#     "ignore_unused_parameters": [true|false]
#     "round_robin_gradients": [true|false]
#     }
#   }
#
# ```

# %% [markdown]
# <video controls src="https://www.microsoft.com/en-us/research/uploads/prod/2020/02/Turing-Animation.mp4?_=1" width="560" />

# %% [markdown]
# In order to illustrate the advantages of ZeRO optimizer in memory saving, let's scale our CNN model to a larger neural network. We  replaced the tiny CNN network with the Resnet152 model with 11 million parameters in the [large_model_deepspeed.py](./code/moe/large_model_deepspeed.py).
#
#
# The following figure shows the CPU usage via [htop](https://htop.dev/) command and the GPU 0 memory profiled using Pytorch Profiler (available on the Tensorboard) for the *resnet152* training step. We can see a comparison between no ZeRO and ZeRO stage 3 + Offload. The memory peak required per GPU without ZeRO optimizer is about 1.1GB, while offloading the parameters to the CPU with ZeRO-3 uses only 360.4MB. On the other hand, the time per step increased significantly from 120ms to 750ms!
#
# ZeRO infinity allows scaling to larger models when the number of GPUs is limited, but this comes with an additional training time corresponding to data movement.
# <img src="images/zero_memory.png" width="1250" />
#
#
# Let's run the Zero stage 3 optimizer and enable CPU offload of the parameters. We have prepared the configuration file. Notice that we have increased the training batch size per GPU to 512.

# %%
# Show DeepSpeed config file for Zero stage 3 Offload
# !cat /dli/code/moe/ds_config_stage_3.json
# Out:
# {
#   "train_batch_size": 512,
#   "steps_per_print": 2000,
#   "optimizer": {
#     "type": "Adam",
#     "params": {
#       "lr": 0.001,
#       "betas": [
#         0.8,
#         0.999
#       ],
#       "eps": 1e-8,
#       "weight_decay": 3e-7
#     }
#   },
#   "scheduler": {
#     "type": "WarmupLR",
#     "params": {
#       "warmup_min_lr": 0,
#       "warmup_max_lr": 0.001,
#       "warmup_num_steps": 1000
#     }
#   },
#   "gradient_clipping": 1.0,
#   "prescale_gradients": false,
#   "fp16": {
#       "enabled": true,
#       "fp16_master_weights_and_grads": false,
#       "loss_scale": 0,
#       "loss_scale_window": 500,
#       "hysteresis": 2,
#       "min_loss_scale": 1,
#       "initial_scale_power": 15
#   },
#   "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 3,
#         "offload_param": {
#           "device": "cpu"
#         },
#         "offload_optimizer": {
#           "device": "cpu"
#         },
#         "cpu_offload_use_pin_memory" : true,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "stage3_max_live_parameters": 1e9,
#         "stage3_max_reuse_distance": 1e9,
#         "stage3_prefetch_bucket_size": 0.94e6,
#         "stage3_param_persistence_threshold": 1e4,
#         "reduce_bucket_size": 1e6,
#         "sub_group_size": 1e14,
#         "stage3_gather_fp16_weights_on_model_save": true
#     }
# }

# %% [markdown]
# First, let's download the resnet152 model. More information about it can be found [here](https://pytorch.org/hub/pytorch_vision_resnet/)

# %%
import torch
net = torch.hub.load("pytorch/vision:v0.10.0", "resnet152", force_reload=True, pretrained=True)
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to /root/.cache/torch/hub/v0.10.0.zip
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]

# %% [markdown]
# Execute the next cell to run the *resnet152* model training on the CIFAR-10 dataset. Notice that in these experiments, our focus is memory consumption as opposed to model accuracy.

# %%
# !deepspeed --num_gpus=4 /dli/code/moe/large_model_deepspeed.py \
    --deepspeed \
    --deepspeed_config /dli/code/moe/ds_config_stage_3.json \
    --profile-execution=True \
    --profile-name='zero_resnet152_stage3'
# Out:
# [2024-03-22 00:53:38,587] [WARNING] [runner.py:159:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2024-03-22 00:53:39,705] [INFO] [runner.py:457:main] cmd = /usr/bin/python -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMSwgMiwgM119 --master_addr=127.0.0.1 --master_port=29500 /dli/code/moe/large_model_deepspeed.py --deepspeed --deepspeed_config /dli/code/moe/ds_config_stage_3.json --profile-execution=True --profile-name=zero_resnet152_stage3
# [2024-03-22 00:53:41,493] [INFO] [launch.py:96:main] 0 NCCL_P2P_DISABLE=1
# [2024-03-22 00:53:41,493] [INFO] [launch.py:96:main] 0 NCCL_VERSION=2.15.5
# [2024-03-22 00:53:41,493] [INFO] [launch.py:103:main] WORLD INFO DICT: {'localhost': [0, 1, 2, 3]}
# [2024-03-22 00:53:41,493] [INFO] [launch.py:109:main] nnodes=1, num_local_procs=4, node_rank=0
# [2024-03-22 00:53:41,493] [INFO] [launch.py:122:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1, 2, 3]})
# [2024-03-22 00:53:41,493] [INFO] [launch.py:123:main] dist_world_size=4
# [2024-03-22 00:53:41,493] [INFO] [launch.py:125:main] Setting CUDA_VISIBLE_DEVICES=0,1,2,3
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [2024-03-22 00:53:54,361] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-22 00:53:54,363] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2024-03-22 00:53:54,836] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-22 00:53:54,901] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-22 00:53:54,961] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# [2024-03-22 00:54:07,342] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py38_cu118/cpu_adam...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/cuda/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.8/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_80,code=compute_80 -gencode=arch=compute_80,code=sm_80 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_80,code=compute_80 -c /usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/cuda/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.8/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/usr/local/cuda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -c /usr/local/lib/python3.8/dist-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/usr/local/lib/python3.8/dist-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 24.58416771888733 seconds
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 24.50489044189453 seconds
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 24.427704334259033 seconds
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 24.531241416931152 seconds
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# [2024-03-22 00:54:33,201] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# [2024-03-22 00:54:33,226] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = DeepSpeedCPUAdam
# [2024-03-22 00:54:33,226] [INFO] [utils.py:52:is_zero_supported_optimizer] Checking ZeRO support for optimizer=DeepSpeedCPUAdam type=<class 'deepspeed.ops.adam.cpu_adam.DeepSpeedCPUAdam'>
# [2024-03-22 00:54:33,226] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 ZeRO stage 3 optimizer
# [2024-03-22 00:54:33,226] [INFO] [engine.py:1410:_configure_zero_optimizer] Initializing ZeRO Stage 3
# [2024-03-22 00:54:33,232] [INFO] [stage3.py:275:__init__] Reduce bucket size 1000000.0
# [2024-03-22 00:54:33,232] [INFO] [stage3.py:276:__init__] Prefetch bucket size 940000.0
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.09908246994018555 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.1021425724029541 seconds
# Loading extension module utils...
# Time to load utils op: 0.10217571258544922 seconds
# Time to load utils op: 0.10267043113708496 seconds
# [2024-03-22 00:54:42,210] [INFO] [stage3.py:567:_setup_for_real_optimizer] optimizer state initialized
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0006663799285888672 seconds
# Time to load utils op: 0.0006895065307617188 seconds
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0008370876312255859 seconds
# [2024-03-22 00:54:42,562] [INFO] [utils.py:828:see_memory_usage] After initializing ZeRO optimizer
# [2024-03-22 00:54:42,563] [INFO] [utils.py:829:see_memory_usage] MA 0.0 GB         Max_MA 0.11 GB         CA 0.12 GB         Max_CA 0 GB
# [2024-03-22 00:54:42,563] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 24.18 GB, percent = 2.8%
# [2024-03-22 00:54:42,563] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2024-03-22 00:54:42,563] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2024-03-22 00:54:42,563] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7effc941ffd0>
# [2024-03-22 00:54:42,563] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2024-03-22 00:54:42,564] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# [2024-03-22 00:54:42,564] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   amp_params ................... False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   dump_state ................... False
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2024-03-22 00:54:42,565] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2024-03-22 00:54:42,566] [INFO] [config.py:1063:print]   pld_params ................... False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   train_batch_size ............. 512
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  128
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   world_size ................... 4
# [2024-03-22 00:54:42,567] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2024-03-22 00:54:42,568] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 3,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 1.000000e+06,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+08,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": {
#         "device": "cpu",
#         "nvme_path": null,
#         "buffer_count": 5,
#         "buffer_size": 1.000000e+08,
#         "max_in_cpu": 1.000000e+09,
#         "pin_memory": false
#     },
#     "offload_optimizer": {
#         "device": "cpu",
#         "nvme_path": null,
#         "buffer_count": 4,
#         "pin_memory": false,
#         "pipeline_read": false,
#         "pipeline_write": false,
#         "fast_init": false,
#         "pipeline": false
#     },
#     "sub_group_size": 1.000000e+14,
#     "prefetch_bucket_size": 9.400000e+05,
#     "param_persistence_threshold": 1.000000e+04,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": true,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2024-03-22 00:54:42,568] [INFO] [config.py:1063:print]   zero_enabled ................. True
# [2024-03-22 00:54:42,568] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 3
# [2024-03-22 00:54:42,568] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 512,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 3,
#         "offload_param": {
#             "device": "cpu"
#         },
#         "offload_optimizer": {
#             "device": "cpu"
#         },
#         "cpu_offload_use_pin_memory": true,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "stage3_max_live_parameters": 1.000000e+09,
#         "stage3_max_reuse_distance": 1.000000e+09,
#         "stage3_prefetch_bucket_size": 9.400000e+05,
#         "stage3_param_persistence_threshold": 1.000000e+04,
#         "reduce_bucket_size": 1.000000e+06,
#         "sub_group_size": 1.000000e+14,
#         "stage3_gather_fp16_weights_on_model_save": true
#     }
# }
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005478858947753906 seconds
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2427: UserWarning: torch.distributed._all_gather_base is a private function and will be deprecated. Please use torch.distributed.all_gather_into_tensor instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2427: UserWarning: torch.distributed._all_gather_base is a private function and will be deprecated. Please use torch.distributed.all_gather_into_tensor instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2427: UserWarning: torch.distributed._all_gather_base is a private function and will be deprecated. Please use torch.distributed.all_gather_into_tensor instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2427: UserWarning: torch.distributed._all_gather_base is a private function and will be deprecated. Please use torch.distributed.all_gather_into_tensor instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2895: UserWarning: torch.distributed._reduce_scatter_base is a private function and will be deprecated. Please use torch.distributed.reduce_scatter_tensor instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2895: UserWarning: torch.distributed._reduce_scatter_base is a private function and will be deprecated. Please use torch.distributed.reduce_scatter_tensor instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2895: UserWarning: torch.distributed._reduce_scatter_base is a private function and will be deprecated. Please use torch.distributed.reduce_scatter_tensor instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:2895: UserWarning: torch.distributed._reduce_scatter_base is a private function and will be deprecated. Please use torch.distributed.reduce_scatter_tensor instead.
#   warnings.warn(
# [2024-03-22 00:54:45,200] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 32768
# [2024-03-22 00:54:48,939] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 16384.0
# STAGE:2024-03-22 00:54:48 18706:18706 ActivityProfilerController.cpp:294] Completed Stage: Warm Up
# [2024-03-22 00:54:49,780] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 16384.0, reducing to 8192.0
# STAGE:2024-03-22 00:54:49 18706:18706 ActivityProfilerController.cpp:300] Completed Stage: Collection
# STAGE:2024-03-22 00:54:53 18706:18706 output_json.cpp:417] Completed Stage: Post Processing
# [2024-03-22 00:54:55,550] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [2024-03-22 00:54:57,392] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 4096.0, reducing to 2048.0
# [2024-03-22 00:55:00,428] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 2048.0, reducing to 1024.0
# Training Done
# Training Done
# Training Done
# Training Done
# Cannot insert a Tensor that requires grad as a constant. Consider making it a parameter or input, or detaching the gradient
# Tensor:
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0138
#  0.0148
# -0.0389
# -0.0044
#  0.1158
#  0.0165
# -0.0283
#  0.0288
#  0.0227
#  0.0035
#  0.0052
#  0.0096
# -0.0197
#  0.0327
#  0.0625
# -0.0291
#  0.0145
#  0.0238
#  0.0223
#  0.0044
# -0.0098
#  0.0296
# -0.0114
# -0.0251
#  0.0079
# -0.0195
# -0.0108
# -0.0036
# -0.0314
# -0.0218
#  0.0132
#  0.0026
# -0.0082
#  0.0085
# -0.0124
# -0.0087
#  0.0113
#  0.0060
# -0.0041
#  0.0171
#  0.0633
#  0.0213
# -0.0268
#  0.0002
# -0.0086
#  0.0151
#  0.0068
#  0.0024
#  0.0232
#  0.0090
# -0.0035
#  0.0073
# -0.0023
# -0.0010
#  0.0487
#  0.0003
#  0.0260
#  0.0391
# -0.0751
# -0.0352
#  0.0681
# -0.0230
# -0.0461
#  0.0225
#  0.0026
# -0.0146
#  0.0428
#  0.0033
# -0.0330
#  0.0041
# -0.0151
# -0.0142
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0098
# -0.0105
# -0.0109
#  0.0121
# -0.0081
#  0.0006
# -0.0201
# -0.0160
#  0.0219
# -0.0144
# -0.0246
# -0.0248
# -0.0220
# -0.0080
#  0.0158
# -0.0384
# -0.0153
#  0.0063
# -0.0149
# -0.0136
# -0.0323
# -0.0262
#  0.0067
# -0.0114
# -0.0306
# -0.0024
# -0.0083
# -0.0053
# -0.0095
# -0.0054
# -0.0067
# -0.0023
#  0.0111
# -0.0043
#  0.0026
#  0.0206
# -0.0065
# -0.0064
#  0.0078
# -0.0334
#  0.0097
#  0.0462
# -0.0190
# -0.0111
# -0.0088
# -0.0076
#  0.0077
# -0.0106
#  0.0004
#  0.0075
#  0.0095
# -0.0059
# -0.0110
# -0.0165
#  0.0245
#  0.0148
#  0.0101
#  0.0436
#  0.0302
#  0.0539
#  0.0244
#  0.0195
#  0.0456
# -0.0245
# -0.0567
#  0.0030
#  0.0052
#  0.0240
#  0.0374
#  0.0063
# -0.0049
# -0.0069
#  0.0052
#  0.0056
#  0.0002
#  0.0128
#  0.0115
# -0.0099
#  0.0059
#  0.0021
# -0.0034
# -0.0031
# -0.0166
# -0.0208
#  0.0130
#  0.0804
# -0.0097
#  0.0023
# -0.0031
# -0.0389
#  0.0397
#  0.0129
# -0.0222
#  0.0728
#  0.0110
# -0.0439
#  0.0056
# -0.0181
# -0.0128
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0096
# -0.0226
# -0.0353
# -0.0077
#  0.0157
#  0.0018
#  0.0090
# -0.0076
#  0.0229
# -0.0010
# -0.0343
# -0.0029
# -0.0135
# -0.0073
#  0.0062
# -0.0007
# -0.0136
#  0.0183
# -0.0111
#  0.0008
# -0.0077
# -0.0106
# -0.0088
# -0.0079
# -0.0135
# -0.0013
# -0.0004
#  0.0491
#  0.0089
#  0.0101
#  0.0350
# -0.0635
# -0.0596
#  0.0337
# -0.0238
# -0.0625
#  0.0384
#  0.0188
#  0.0117
#  0.0302
#  0.0653
#  0.0497
# -0.0092
#  0.0325
#  0.0419
#  0.0402
#  0.0026
#  0.0165
# -0.0090
# -0.0250
#  0.0146
# -0.0058
# -0.0105
#  0.0300
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0143
#  0.0125
#  0.0048
#  0.0268
#  0.0175
# -0.0005
#  0.0157
#  0.0066
#  0.0042
# -0.0017
#  0.0020
#  0.0024
# -0.0019
#  0.0047
#  0.0045
# -0.0011
#  0.0044
#  0.0030
#  0.0115
#  0.0136
# -0.0001
# -0.0190
#  0.0217
# -0.0357
#  0.0218
#  0.0279
# -0.0098
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0226
# -0.0117
# -0.0042
#  0.0133
#  0.0559
#  0.0123
#  0.0101
#  0.0080
#  0.0116
# -0.0136
#  0.0030
#  0.0069
# -0.0111
#  0.0404
#  0.0395
# -0.0031
#  0.0147
#  0.0186
# -0.0064
# -0.0148
# -0.0009
#  0.0123
# -0.0165
#  0.0165
# -0.0229
# -0.0219
#  0.0015
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0073
# -0.0149
# -0.0183
#  0.0028
#  0.0201
#  0.0285
# -0.0062
#  0.0132
#  0.0114
#  0.0089
#  0.0068
# -0.0018
#  0.0202
#  0.0127
# -0.0006
#  0.0078
# -0.0041
# -0.0021
# -0.0146
# -0.0074
#  0.0124
# -0.0002
#  0.0124
#  0.0097
#  0.0153
#  0.0061
# -0.0164
#  0.0076
#  0.0045
# -0.0003
#  0.0051
#  0.0024
# -0.0001
#  0.0033
# -0.0022
# -0.0042
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0160
#  0.0044
#  0.0023
#  0.0207
#  0.0086
# -0.0164
#  0.0404
# -0.0017
#  0.0008
# -0.0047
# -0.0088
#  0.0106
#  0.0111
#  0.0620
#  0.0160
# -0.0048
#  0.0071
#  0.0109
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0132
#  0.0011
#  0.0027
#  0.0176
# -0.0049
# -0.0016
#  0.0039
#  0.0024
#  0.0128
# -0.0015
# -0.0105
#  0.0023
# -0.0251
#  0.0051
#  0.0262
# -0.0020
# -0.0027
# -0.0108
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0070
# -0.0128
#  0.0020
# -0.0104
#  0.0049
#  0.0263
#  0.0052
#  0.0059
#  0.0132
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0070
# -0.0100
# -0.0087
#  0.0095
# -0.0119
# -0.0144
#  0.0268
# -0.0165
# -0.0073
#  0.0011
#  0.0396
#  0.0116
#  0.0250
#  0.0507
#  0.0048
# -0.0061
# -0.0211
#  0.0142
# -0.0061
# -0.0141
#  0.0088
#  0.0060
#  0.0183
#  0.0086
#  0.0187
#  0.0174
#  0.0083
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0239
#  0.0198
# -0.0362
#  0.0062
#  0.1617
#  0.0274
# -0.0348
#  0.0202
# -0.0094
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0037
#  0.0172
# -0.0040
# -0.0163
#  0.0349
#  0.0085
#  0.0086
#  0.0038
#  0.0046
#  0.0675
#  0.0876
#  0.0797
#  0.0205
# -0.1176
#  0.0000
#  0.0504
#  0.0011
#  0.0681
#  0.0280
#  0.0167
# -0.0040
# -0.0030
#  0.0162
# -0.0279
#  0.0078
# -0.0044
# -0.0396
# -0.0176
# -0.0378
#  0.0080
#  0.0161
#  0.0731
#  0.0361
# -0.0023
# -0.0019
# -0.0269
# -0.0216
# -0.0446
# -0.0553
# -0.0397
#  0.0180
#  0.0397
#  0.0412
# -0.0919
#  0.0688
# -0.0017
# -0.0215
# -0.0318
#  0.0140
#  0.1266
#  0.0024
#  0.0081
#  0.0323
# -0.0182
# -0.0109
# -0.0417
# -0.0685
# -0.0350
#  0.1560
# -0.1508
# -0.0055
#  0.0050
# -0.0601
#  0.0640
#  0.0377
#  0.0184
#  0.0333
#  0.0420
#  0.0060
#  0.0085
#  0.0119
# -0.0309
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0439
#  0.0288
#  0.0238
#  0.0599
#  0.0245
# -0.0375
#  0.0440
# -0.0448
# -0.0327
#  0.0364
#  0.0066
#  0.0312
#  0.0283
#  0.0493
# -0.0635
#  0.0117
#  0.0811
# -0.0187
#  0.0077
# -0.0092
#  0.0019
#  0.0085
#  0.0495
#  0.0597
#  0.0031
# -0.0393
#  0.0117
# -0.0458
# -0.0269
# -0.0133
#  0.0107
#  0.0322
# -0.0261
#  0.0094
#  0.0161
# -0.0191
#  0.0687
#  0.0722
#  0.0843
# -0.0210
# -0.1465
# -0.0114
#  0.0424
# -0.0406
#  0.0130
#  0.0057
#  0.0412
# -0.0043
# -0.0261
# -0.0446
# -0.0083
# -0.0216
# -0.0336
# -0.0457
# -0.0347
#  0.0241
# -0.0433
# -0.0259
#  0.0707
# -0.0332
#  0.0008
#  0.0221
# -0.0612
# -0.0229
#  0.0157
# -0.0017
# -0.0005
#  0.0447
# -0.0714
# -0.0262
# -0.0220
#  0.0442
# -0.0031
# -0.0267
# -0.0383
# -0.0309
#  0.0747
#  0.0118
#  0.0048
#  0.0438
# -0.0082
# -0.0056
#  0.0030
#  0.0096
#  0.0110
# -0.0710
#  0.0911
# -0.0110
# -0.0333
#  0.0763
#  0.0871
#  0.0887
#  0.0265
#  0.0436
#  0.0403
# -0.0091
#  0.0165
#  0.0141
# -0.0404
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0186
#  0.0011
# -0.0129
# -0.0364
# -0.0431
#  0.0833
#  0.0070
# -0.0247
#  0.0133
# -0.0065
# -0.0132
# -0.0173
#  0.0111
#  0.0296
#  0.0098
# -0.0006
#  0.0166
#  0.0168
#  0.0374
#  0.0073
#  0.0236
#  0.0038
#  0.0164
#  0.0164
#  0.0341
#  0.0313
#  0.0265
#  0.0053
# -0.0422
# -0.0338
# -0.0102
#  0.0710
#  0.0562
#  0.0079
#  0.0734
#  0.0099
#  0.0045
#  0.0100
# -0.0372
# -0.0032
# -0.0486
# -0.0779
# -0.0146
#  0.0106
#  0.0016
# -0.0213
# -0.0026
#  0.0086
# -0.0004
#  0.0569
# -0.0096
# -0.0300
#  0.0387
# -0.0210
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0098
# -0.0322
# -0.0357
# -0.0029
#  0.1420
#  0.0048
# -0.0002
#  0.0404
# -0.0204
#  0.0064
#  0.0003
#  0.0135
#  0.0071
# -0.0031
#  0.0145
#  0.0071
#  0.0064
#  0.0181
# -0.0023
#  0.0021
# -0.0309
# -0.0123
#  0.0151
# -0.0348
# -0.0157
#  0.0190
# -0.0177
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0187
#  0.0324
# -0.0144
# -0.0155
#  0.0934
#  0.0386
#  0.0132
#  0.0129
# -0.0618
#  0.0154
# -0.0181
#  0.0328
# -0.0204
# -0.0745
# -0.0153
#  0.0157
# -0.0087
#  0.0403
#  0.0204
#  0.0030
#  0.0032
# -0.0370
# -0.0195
# -0.0457
# -0.0201
# -0.0064
# -0.0180
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0031
# -0.0281
# -0.0220
# -0.0124
#  0.0478
# -0.0531
# -0.0303
# -0.0099
#  0.0089
# -0.0073
# -0.0622
# -0.0173
# -0.0274
#  0.0704
#  0.0656
# -0.0092
# -0.0003
#  0.0097
# -0.0415
#  0.0541
#  0.0603
# -0.0294
# -0.1582
# -0.1377
# -0.0082
#  0.1456
#  0.0782
# -0.0032
# -0.0038
# -0.0024
# -0.0097
# -0.0070
# -0.0093
#  0.0018
#  0.0033
# -0.0005
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0224
# -0.0079
#  0.0156
# -0.0106
#  0.0058
#  0.0004
# -0.0006
# -0.0207
# -0.0279
#  0.0252
#  0.0269
# -0.0059
# -0.0241
#  0.0217
#  0.0045
# -0.0217
#  0.0133
#  0.0233
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0076
# -0.0389
# -0.0181
#  0.0233
#  0.0273
# -0.0433
#  0.0257
# -0.0003
# -0.0319
#  0.0311
#  0.0428
#  0.0490
#  0.0042
# -0.0762
# -0.0058
#  0.0099
# -0.0293
#  0.0334
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0175
#  0.0386
#  0.0319
#  0.0269
#  0.0294
#  0.0124
#  0.0196
#  0.0576
#  0.0489
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0218
# -0.0495
# -0.0037
# -0.0042
# -0.0595
#  0.1403
#  0.0060
# -0.0506
# -0.0421
#  0.0159
# -0.0543
#  0.0368
# -0.0454
# -0.0447
#  0.0291
#  0.0210
#  0.0605
# -0.1367
#  0.0181
# -0.0087
# -0.0119
# -0.0435
# -0.0602
# -0.0400
# -0.0126
#  0.0102
#  0.0229
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0036
# -0.0457
#  0.0175
# -0.0218
# -0.0929
#  0.0192
#  0.0079
# -0.0550
# -0.0007
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0125
# -0.0203
# -0.0109
# -0.0283
# -0.0318
# -0.0231
# -0.0075
#  0.0244
#  0.0180
# -0.0654
# -0.1512
# -0.1068
# -0.0596
# -0.0223
# -0.0175
#  0.0752
#  0.2515
#  0.2021
#  0.0526
#  0.1177
#  0.0633
#  0.0070
#  0.0302
# -0.0075
# -0.0286
# -0.0857
# -0.0587
# -0.0088
# -0.0097
#  0.0146
#  0.0183
#  0.0097
#  0.0167
#  0.0088
#  0.0041
# -0.0094
# -0.0193
# -0.0193
#  0.0183
# -0.0680
# -0.0758
# -0.0076
# -0.0003
#  0.0264
#  0.0155
#  0.0608
#  0.0856
#  0.0458
#  0.0068
#  0.0037
# -0.0075
# -0.0585
# -0.0954
# -0.0757
#  0.0079
#  0.0809
#  0.0253
# -0.0046
# -0.0406
# -0.0329
# -0.0039
# -0.0523
# -0.0211
#  0.0814
#  0.1710
#  0.1129
# -0.0078
#  0.0302
# -0.0132
# -0.0503
# -0.1146
# -0.0993
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0135
#  0.0131
# -0.0289
# -0.0061
#  0.0141
# -0.0172
# -0.0144
# -0.0376
# -0.0124
#  0.0120
#  0.0267
# -0.0117
# -0.0285
#  0.0142
# -0.0087
# -0.0145
#  0.0067
#  0.0297
# -0.0026
# -0.0526
# -0.0245
# -0.0056
# -0.0120
#  0.0242
# -0.0131
# -0.0083
#  0.0402
#  0.0468
#  0.0555
# -0.0479
#  0.0103
#  0.0091
# -0.0075
# -0.0408
# -0.0265
#  0.0429
# -0.0980
# -0.2042
# -0.1203
# -0.0609
# -0.0195
# -0.0173
#  0.1006
#  0.3088
#  0.2371
#  0.0036
# -0.0131
#  0.0179
#  0.0250
#  0.0242
#  0.0177
# -0.0058
# -0.0156
# -0.0063
# -0.0143
#  0.0054
#  0.0074
# -0.0237
# -0.0214
# -0.0279
#  0.0047
# -0.0148
# -0.0007
#  0.0091
#  0.0173
#  0.0285
# -0.0250
# -0.0197
# -0.0250
#  0.0232
#  0.0321
# -0.0011
#  0.0538
#  0.0681
#  0.0530
#  0.0027
# -0.0044
# -0.0024
# -0.0332
# -0.0569
# -0.0616
#  0.0161
#  0.0029
#  0.0178
# -0.0244
# -0.0372
# -0.0106
#  0.0001
#  0.0233
#  0.0198
#  0.1362
#  0.2734
#  0.1565
# -0.0146
#  0.0555
# -0.0345
# -0.0892
# -0.1799
# -0.1523
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0234
# -0.0080
#  0.0338
# -0.0017
# -0.0150
# -0.0106
#  0.0235
#  0.0389
#  0.0055
# -0.0179
#  0.0078
# -0.0089
# -0.0050
#  0.0666
#  0.0339
# -0.0089
#  0.0145
#  0.0080
#  0.0059
#  0.0417
#  0.0224
#  0.0133
#  0.0639
#  0.0270
# -0.0010
# -0.0188
# -0.0229
# -0.0031
#  0.0756
#  0.0862
#  0.0059
# -0.0714
# -0.0015
#  0.0175
# -0.0657
# -0.0500
# -0.0179
# -0.0055
# -0.0138
# -0.0440
# -0.0012
# -0.0444
# -0.0254
#  0.0596
# -0.0049
# -0.0111
# -0.0440
# -0.0234
#  0.0299
#  0.0019
#  0.0160
#  0.0150
# -0.0597
# -0.0115
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0332
#  0.0760
#  0.0387
# -0.0064
# -0.0144
# -0.0122
# -0.0492
# -0.0959
# -0.0826
# -0.0030
# -0.0109
# -0.0063
#  0.0011
#  0.0007
#  0.0015
#  0.0076
#  0.0145
#  0.0146
#  0.0141
# -0.0101
#  0.0118
# -0.0031
# -0.0364
# -0.0145
#  0.0240
#  0.0184
#  0.0367
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0125
# -0.0212
# -0.0049
# -0.0073
#  0.0086
# -0.0175
#  0.0245
#  0.0129
#  0.0021
# -0.0289
# -0.0474
# -0.0455
# -0.0226
#  0.0010
# -0.0073
#  0.0158
#  0.0767
#  0.0382
# -0.0073
#  0.0515
#  0.0213
#  0.0041
#  0.0230
#  0.0122
# -0.0055
# -0.0138
#  0.0014
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0091
# -0.0043
#  0.0005
# -0.0347
# -0.0188
# -0.0425
# -0.0079
#  0.0260
#  0.0234
#  0.0328
#  0.0935
#  0.0889
#  0.0110
# -0.0001
# -0.0020
# -0.0333
# -0.0921
# -0.1008
# -0.0090
#  0.0567
#  0.0253
# -0.0593
#  0.0082
# -0.0407
# -0.0095
#  0.0779
#  0.0238
#  0.0014
# -0.0021
# -0.0013
# -0.0017
# -0.0051
# -0.0048
#  0.0044
#  0.0079
#  0.0093
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0235
#  0.0434
#  0.0437
# -0.0106
#  0.0229
# -0.0034
#  0.0062
#  0.0057
# -0.0009
# -0.0045
# -0.0046
#  0.0110
#  0.0117
#  0.0462
#  0.0431
#  0.0216
#  0.0275
#  0.0056
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0284
#  0.0453
# -0.0065
# -0.0033
#  0.0035
# -0.0180
# -0.0302
# -0.0474
# -0.0272
# -0.0593
# -0.1356
# -0.0582
# -0.0568
# -0.0383
# -0.0257
#  0.0842
#  0.2274
#  0.1660
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0102
# -0.0361
# -0.0349
# -0.0190
# -0.0254
# -0.0187
#  0.0073
#  0.0542
#  0.0347
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0319
# -0.0050
#  0.0187
# -0.0131
#  0.0242
#  0.0270
#  0.0114
#  0.0036
#  0.0098
# -0.0009
#  0.0112
# -0.0259
# -0.0288
#  0.0114
# -0.0758
#  0.0340
#  0.0467
# -0.0156
# -0.0403
#  0.0439
#  0.0018
# -0.0236
#  0.0854
#  0.0256
# -0.0182
#  0.0498
#  0.0090
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0171
# -0.0121
# -0.0080
# -0.0256
# -0.0016
#  0.0164
# -0.0311
#  0.0128
#  0.0117
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0023
#  0.0148
#  0.0108
#  0.0079
#  0.0085
# -0.0008
# -0.0012
#  0.0118
# -0.0106
# -0.0026
# -0.0081
# -0.0172
# -0.0002
# -0.0068
# -0.0154
#  0.0023
# -0.0048
#  0.0063
#  0.0044
#  0.0124
#  0.0014
# -0.0067
# -0.0012
# -0.0002
# -0.0083
# -0.0007
# -0.0009
# -0.0106
#  0.0040
#  0.0157
#  0.0085
#  0.0161
#  0.0116
#  0.0188
#  0.0106
#  0.0009
# -0.0093
# -0.0086
#  0.0134
# -0.0106
# -0.0113
# -0.0018
#  0.0010
#  0.0062
# -0.0108
# -0.0089
# -0.0056
# -0.0077
# -0.0091
# -0.0076
#  0.0014
# -0.0040
# -0.0042
# -0.0022
# -0.0226
#  0.0002
# -0.0105
# -0.0030
#  0.0140
#  0.0010
#  0.0032
#  0.0154
# -0.0173
#  0.0060
#  0.0127
#  0.0065
# -0.0095
# -0.0073
# -0.0014
# -0.0062
# -0.0030
#  0.0017
# -0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0087
#  0.0178
#  0.0086
# -0.0092
#  0.0041
#  0.0081
# -0.0056
#  0.0033
#  0.0026
# -0.0191
# -0.0204
# -0.0295
# -0.0228
# -0.0173
# -0.0198
# -0.0235
# -0.0239
# -0.0245
# -0.0165
# -0.0185
# -0.0126
# -0.0144
# -0.0405
# -0.0152
# -0.0105
# -0.0097
# -0.0191
# -0.0002
# -0.0049
# -0.0017
# -0.0038
# -0.0002
#  0.0021
#  0.0027
# -0.0004
# -0.0073
# -0.0099
# -0.0081
# -0.0188
#  0.0052
#  0.0101
# -0.0104
#  0.0068
#  0.0076
#  0.0092
# -0.0094
# -0.0208
# -0.0065
#  0.0034
#  0.0133
#  0.0060
#  0.0026
#  0.0001
#  0.0052
#  0.0009
#  0.0051
#  0.0015
# -0.0002
#  0.0108
# -0.0054
# -0.0027
#  0.0128
# -0.0109
#  0.0087
#  0.0226
#  0.0308
#  0.0255
#  0.0392
#  0.0291
#  0.0291
#  0.0264
#  0.0107
#  0.0015
#  0.0012
# -0.0028
# -0.0005
# -0.0061
#  0.0013
# -0.0015
#  0.0025
#  0.0079
# -0.0081
#  0.0137
#  0.0186
# -0.0012
#  0.0235
#  0.0081
# -0.0022
#  0.0074
#  0.0095
#  0.0087
#  0.0128
#  0.0073
# -0.0147
# -0.0122
#  0.0010
# -0.0084
# -0.0047
#  0.0067
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0124
# -0.0027
#  0.0089
# -0.0105
# -0.0140
# -0.0225
# -0.0059
# -0.0057
# -0.0140
#  0.0025
#  0.0106
#  0.0102
#  0.0067
#  0.0125
#  0.0146
#  0.0197
#  0.0078
#  0.0124
#  0.0160
#  0.0008
# -0.0076
#  0.0115
#  0.0066
#  0.0135
#  0.0121
#  0.0043
#  0.0250
# -0.0224
# -0.0054
# -0.0067
# -0.0111
# -0.0172
# -0.0211
# -0.0055
# -0.0004
# -0.0177
#  0.0024
# -0.0007
# -0.0132
# -0.0079
# -0.0019
# -0.0031
# -0.0107
# -0.0108
# -0.0162
# -0.0145
#  0.0005
#  0.0087
# -0.0181
# -0.0134
# -0.0003
# -0.0067
# -0.0065
#  0.0026
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0074
# -0.0043
# -0.0092
# -0.0070
# -0.0135
# -0.0024
# -0.0063
# -0.0045
#  0.0034
# -0.0037
# -0.0013
#  0.0007
#  0.0023
#  0.0071
#  0.0046
#  0.0024
#  0.0017
#  0.0041
# -0.0027
#  0.0146
#  0.0127
#  0.0217
#  0.0216
#  0.0080
#  0.0219
#  0.0155
# -0.0103
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0203
#  0.0204
#  0.0238
#  0.0265
#  0.0405
#  0.0250
#  0.0147
#  0.0319
#  0.0166
# -0.0040
# -0.0099
# -0.0078
#  0.0003
#  0.0072
#  0.0039
#  0.0026
#  0.0007
#  0.0006
# -0.0055
# -0.0073
# -0.0255
# -0.0115
# -0.0194
# -0.0251
# -0.0302
# -0.0212
# -0.0034
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0250
# -0.0061
# -0.0117
# -0.0178
# -0.0057
# -0.0053
# -0.0099
# -0.0049
# -0.0127
# -0.0076
# -0.0009
# -0.0088
# -0.0003
# -0.0106
# -0.0088
# -0.0038
# -0.0020
# -0.0009
# -0.0047
# -0.0166
# -0.0105
# -0.0013
#  0.0244
#  0.0273
#  0.0005
# -0.0151
#  0.0018
# -0.0073
# -0.0079
# -0.0106
#  0.0027
#  0.0023
# -0.0112
# -0.0032
# -0.0051
# -0.0102
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0107
#  0.0227
#  0.0146
#  0.0054
#  0.0282
#  0.0171
#  0.0045
#  0.0167
#  0.0073
#  0.0005
#  0.0090
#  0.0123
#  0.0119
#  0.0223
#  0.0148
#  0.0103
#  0.0120
#  0.0162
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0014
# -0.0025
# -0.0062
# -0.0082
# -0.0057
# -0.0117
# -0.0073
# -0.0005
# -0.0099
# -0.0116
# -0.0043
# -0.0035
#  0.0035
#  0.0141
# -0.0009
#  0.0120
#  0.0096
#  0.0045
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0105
# -0.0120
# -0.0041
# -0.0007
#  0.0038
#  0.0001
# -0.0022
#  0.0019
# -0.0050
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0001
#  0.0021
#  0.0020
# -0.0088
# -0.0154
# -0.0126
# -0.0106
# -0.0052
#  0.0135
#  0.0166
# -0.0000
#  0.0186
#  0.0106
#  0.0222
# -0.0049
# -0.0049
#  0.0088
#  0.0078
# -0.0012
#  0.0040
# -0.0011
# -0.0033
# -0.0016
# -0.0039
# -0.0067
# -0.0171
# -0.0036
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0036
# -0.0035
#  0.0208
# -0.0068
# -0.0278
# -0.0130
# -0.0159
# -0.0181
# -0.0037
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# ...
# -0.0010
# -0.0009
#  0.0027
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0347
#  0.0678
#  0.0409
# -0.0291
# -0.0463
# -0.0284
# -0.0268
# -0.0771
# -0.0310
#  0.0151
#  0.0381
# -0.0040
#  0.0100
# -0.0110
#  0.0058
#  0.0119
# -0.0138
# -0.0303
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0043
#  0.0008
# -0.0161
# -0.0051
# -0.0045
#  0.0080
#  0.0008
#  0.0028
#  0.0149
#  0.0181
#  0.0189
#  0.0194
# -0.0082
#  0.0073
#  0.0070
# -0.0059
#  0.0219
# -0.0056
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0462
# -0.0654
# -0.0600
#  0.0024
#  0.0110
#  0.0119
#  0.0277
#  0.0792
#  0.0696
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0494
# -0.0008
#  0.0220
#  0.0006
#  0.0198
# -0.0246
# -0.0259
#  0.0462
# -0.0168
#  0.0266
#  0.0223
# -0.0450
#  0.0142
#  0.0092
# -0.0162
# -0.0468
# -0.0293
#  0.0277
#  0.0166
#  0.0577
#  0.0295
# -0.0043
#  0.0166
#  0.0226
# -0.0356
# -0.0070
# -0.0155
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0383
#  0.0540
#  0.0144
#  0.0411
# -0.0135
# -0.0631
#  0.0260
# -0.0407
# -0.0444
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0495
#  0.0249
#  0.0522
#  0.0231
# -0.0375
#  0.0242
# -0.0025
# -0.0303
#  0.0171
#  0.0001
# -0.0779
# -0.0345
# -0.0051
# -0.0432
#  0.0150
#  0.0100
# -0.0331
#  0.0109
# -0.0425
# -0.0066
# -0.0159
# -0.0391
#  0.0068
# -0.0054
# -0.0362
#  0.0066
#  0.0029
#  0.0017
#  0.0070
# -0.0124
#  0.0155
# -0.0254
# -0.0016
#  0.0209
#  0.0160
# -0.0103
#  0.0108
#  0.0131
#  0.0474
#  0.0044
# -0.0295
#  0.0352
# -0.0126
# -0.0210
#  0.0273
# -0.0073
#  0.0031
#  0.0023
#  0.0010
#  0.0010
#  0.0071
# -0.0176
# -0.0041
#  0.0055
# -0.0933
#  0.0060
# -0.0258
# -0.0040
#  0.1225
# -0.0054
# -0.0089
#  0.0635
# -0.0371
# -0.0335
# -0.0048
#  0.0086
# -0.0549
#  0.0017
#  0.0004
# -0.0327
#  0.0363
#  0.0256
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0127
#  0.0084
#  0.0199
# -0.0217
#  0.0029
# -0.0020
# -0.0260
#  0.0157
# -0.0037
#  0.0214
# -0.0173
# -0.0223
# -0.0136
# -0.0251
# -0.0131
# -0.0349
#  0.0231
# -0.0027
#  0.0081
# -0.0323
# -0.0111
# -0.0025
# -0.0428
# -0.0114
#  0.0011
# -0.0041
#  0.0242
#  0.0194
#  0.0001
#  0.0020
# -0.0068
# -0.0320
#  0.0015
#  0.0407
# -0.0212
#  0.0059
# -0.0294
# -0.0967
# -0.0641
#  0.0066
# -0.0325
#  0.0168
#  0.0107
# -0.0501
#  0.0079
# -0.0099
#  0.0026
# -0.0071
# -0.0208
# -0.0529
# -0.0406
#  0.0016
#  0.0155
#  0.0195
# -0.0001
# -0.0249
#  0.0143
# -0.0071
# -0.0401
# -0.0217
# -0.0231
# -0.0451
# -0.0332
#  0.0022
#  0.0508
#  0.0051
#  0.0315
#  0.0244
# -0.0393
#  0.0250
#  0.0027
#  0.0213
# -0.0048
#  0.0109
#  0.0201
# -0.0003
# -0.0031
#  0.0141
# -0.0072
#  0.0077
#  0.0124
#  0.0228
# -0.0033
#  0.0322
#  0.0166
# -0.0171
#  0.0431
#  0.0139
# -0.0062
#  0.0407
# -0.0604
# -0.0164
#  0.0021
# -0.1019
# -0.0091
# -0.0071
# -0.0773
#  0.0265
#  0.0283
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0286
# -0.0048
#  0.0061
#  0.0024
# -0.0344
# -0.0018
#  0.0159
# -0.0018
#  0.0080
#  0.0358
#  0.0235
#  0.0139
#  0.0453
# -0.0322
# -0.0007
#  0.0237
# -0.0353
# -0.0234
#  0.0075
# -0.0033
#  0.0046
#  0.0006
# -0.0421
# -0.0057
#  0.0001
# -0.0201
# -0.0140
# -0.0900
# -0.0298
#  0.0026
# -0.0375
#  0.0585
#  0.0257
# -0.0300
#  0.0564
#  0.0273
#  0.0007
#  0.0071
# -0.0109
# -0.0005
# -0.0027
# -0.0485
# -0.0190
# -0.0210
# -0.0627
#  0.0416
#  0.0388
#  0.0235
#  0.0226
#  0.0327
#  0.0434
#  0.0361
#  0.0309
#  0.0182
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0159
# -0.0051
#  0.0116
#  0.0128
#  0.0065
#  0.0138
# -0.0012
#  0.0204
#  0.0125
#  0.0018
# -0.0041
# -0.0042
# -0.0029
# -0.0035
# -0.0018
# -0.0053
# -0.0063
# -0.0036
# -0.0173
# -0.0078
#  0.0167
#  0.0040
#  0.0037
#  0.0608
# -0.0274
# -0.0159
#  0.0267
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0140
# -0.0015
#  0.0207
# -0.0003
# -0.0101
#  0.0034
# -0.0030
# -0.0144
#  0.0069
#  0.0102
# -0.0286
# -0.0352
#  0.0016
# -0.0272
# -0.0021
#  0.0047
# -0.0150
# -0.0128
#  0.0287
#  0.0218
# -0.0034
#  0.0171
#  0.0271
# -0.0242
#  0.0291
#  0.0434
# -0.0159
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0135
# -0.0076
# -0.0182
#  0.0204
#  0.0229
# -0.0164
#  0.0052
#  0.0327
# -0.0066
# -0.0096
#  0.0121
#  0.0099
#  0.0049
#  0.0066
#  0.0147
# -0.0029
#  0.0247
#  0.0178
# -0.0384
# -0.0082
# -0.0182
# -0.0240
#  0.0351
#  0.0202
#  0.0105
# -0.0205
# -0.0351
# -0.0001
# -0.0050
# -0.0061
#  0.0029
# -0.0044
# -0.0046
# -0.0005
# -0.0071
# -0.0065
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0295
# -0.0142
# -0.0225
# -0.0121
#  0.0101
#  0.0096
# -0.0218
# -0.0255
# -0.0120
#  0.0035
# -0.0061
#  0.0097
#  0.0028
# -0.0108
#  0.0007
#  0.0162
# -0.0311
# -0.0082
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0055
#  0.0095
#  0.0046
# -0.0021
#  0.0139
# -0.0074
# -0.0044
#  0.0136
# -0.0060
# -0.0166
# -0.0546
# -0.0312
#  0.0085
# -0.0085
#  0.0191
#  0.0128
# -0.0207
#  0.0054
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0041
# -0.0043
# -0.0016
#  0.0251
#  0.0045
#  0.0139
#  0.0034
# -0.0058
# -0.0101
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0163
# -0.0227
# -0.0091
#  0.0075
# -0.0648
# -0.0370
#  0.0323
# -0.0004
#  0.0113
#  0.0044
#  0.0498
#  0.0034
# -0.0079
# -0.0130
# -0.0113
#  0.0060
# -0.0176
# -0.0271
# -0.0122
# -0.0032
# -0.0103
# -0.0217
# -0.0056
#  0.0034
# -0.0024
# -0.0341
# -0.0301
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0293
# -0.0055
#  0.0355
# -0.0414
# -0.0297
#  0.0314
# -0.0247
# -0.0159
#  0.0661
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0017
# -0.0066
# -0.0123
#  0.0014
#  0.0301
#  0.0007
# -0.0072
#  0.0070
#  0.0008
#  0.0274
#  0.0229
# -0.0012
#  0.0242
#  0.0148
# -0.0340
# -0.0044
# -0.0236
# -0.0422
# -0.0038
#  0.0044
#  0.0159
# -0.0076
#  0.0053
#  0.0263
# -0.0032
#  0.0178
#  0.0257
# -0.0126
# -0.0227
#  0.0087
# -0.0109
# -0.0214
# -0.0028
#  0.0041
# -0.0126
# -0.0043
#  0.0145
#  0.0119
#  0.0324
# -0.0020
#  0.0102
#  0.0221
#  0.0113
#  0.0026
#  0.0126
# -0.0175
# -0.0138
#  0.0021
# -0.0076
# -0.0114
#  0.0067
# -0.0023
#  0.0051
#  0.0182
#  0.0257
#  0.0273
#  0.0507
# -0.0049
# -0.0317
#  0.0067
#  0.0182
#  0.0042
#  0.0021
# -0.0254
# -0.0069
#  0.0062
# -0.0270
# -0.0013
#  0.0233
# -0.0122
#  0.0163
#  0.0447
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0170
# -0.0125
# -0.0135
# -0.0072
#  0.0235
#  0.0047
# -0.0146
#  0.0190
#  0.0120
# -0.0283
# -0.0163
# -0.0210
# -0.0149
# -0.0273
# -0.0183
# -0.0151
# -0.0114
#  0.0100
# -0.0010
# -0.0069
# -0.0112
#  0.0043
# -0.0197
# -0.0110
# -0.0016
# -0.0183
# -0.0089
# -0.0003
#  0.0012
#  0.0100
# -0.0095
# -0.0059
#  0.0042
# -0.0020
#  0.0045
# -0.0052
#  0.0494
#  0.0390
#  0.0148
#  0.0367
#  0.0093
# -0.0433
#  0.0037
# -0.0311
# -0.0608
#  0.0119
#  0.0209
#  0.0282
#  0.0193
#  0.0165
#  0.0104
#  0.0248
#  0.0242
#  0.0063
# -0.0086
#  0.0061
# -0.0203
# -0.0013
#  0.0640
#  0.0083
# -0.0106
#  0.0267
#  0.0060
#  0.0250
#  0.0039
#  0.0161
#  0.0068
#  0.0188
#  0.0210
#  0.0202
# -0.0030
#  0.0276
# -0.0073
# -0.0071
# -0.0024
# -0.0097
# -0.0057
#  0.0126
#  0.0022
#  0.0106
#  0.0277
#  0.0170
#  0.0094
#  0.0144
#  0.0116
#  0.0192
#  0.0049
# -0.0044
#  0.0021
#  0.0116
# -0.0356
# -0.0073
#  0.0146
# -0.0430
#  0.0061
#  0.0427
# -0.0217
#  0.0339
#  0.0768
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0046
# -0.0177
# -0.0123
# -0.0148
# -0.0367
# -0.0168
# -0.0079
# -0.0254
# -0.0146
# -0.0044
# -0.0195
# -0.0008
#  0.0026
# -0.0059
# -0.0048
# -0.0089
# -0.0101
# -0.0009
# -0.0088
# -0.0093
# -0.0016
#  0.0109
#  0.0113
#  0.0089
# -0.0074
#  0.0002
#  0.0003
#  0.0150
#  0.0156
#  0.0310
# -0.0146
# -0.0451
# -0.0048
#  0.0180
# -0.0107
# -0.0062
#  0.0154
#  0.0333
# -0.0092
#  0.0168
#  0.0652
#  0.0127
# -0.0092
#  0.0357
#  0.0206
#  0.0007
# -0.0144
# -0.0014
#  0.0011
#  0.0253
#  0.0322
# -0.0094
#  0.0076
#  0.0114
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0159
# -0.0145
#  0.0073
# -0.0062
# -0.0117
#  0.0102
#  0.0095
#  0.0106
#  0.0270
#  0.0003
#  0.0016
# -0.0017
#  0.0003
# -0.0016
# -0.0063
# -0.0040
# -0.0046
# -0.0062
#  0.0064
#  0.0089
#  0.0057
# -0.0144
#  0.0080
# -0.0202
#  0.0085
# -0.0074
# -0.0177
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0180
#  0.0110
#  0.0150
#  0.0129
#  0.0484
#  0.0197
#  0.0176
#  0.0227
#  0.0230
#  0.0281
#  0.0167
# -0.0022
#  0.0276
#  0.0114
# -0.0105
#  0.0111
# -0.0019
# -0.0026
#  0.0118
#  0.0060
# -0.0012
#  0.0011
# -0.0134
# -0.0018
# -0.0157
# -0.0019
#  0.0016
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0150
# -0.0072
# -0.0146
# -0.0094
# -0.0324
# -0.0225
# -0.0076
# -0.0083
# -0.0027
# -0.0040
# -0.0121
#  0.0063
#  0.0003
# -0.0090
#  0.0305
#  0.0100
#  0.0007
#  0.0323
# -0.0074
# -0.0073
# -0.0103
# -0.0278
# -0.0138
# -0.0172
# -0.0065
# -0.0030
#  0.0046
#  0.0100
#  0.0079
#  0.0062
#  0.0021
#  0.0026
#  0.0026
# -0.0046
# -0.0050
# -0.0069
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0060
#  0.0043
#  0.0007
# -0.0065
# -0.0071
#  0.0026
# -0.0096
#  0.0041
#  0.0086
#  0.0385
#  0.0139
#  0.0111
#  0.0366
#  0.0521
#  0.0363
#  0.0209
#  0.0161
#  0.0280
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0025
#  0.0048
#  0.0074
# -0.0031
#  0.0056
#  0.0102
# -0.0037
#  0.0079
#  0.0052
#  0.0286
#  0.0195
#  0.0072
#  0.0158
# -0.0057
# -0.0365
#  0.0016
# -0.0329
# -0.0470
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0067
#  0.0027
#  0.0027
#  0.0004
# -0.0061
# -0.0075
#  0.0002
# -0.0104
# -0.0070
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0021
# -0.0154
# -0.0104
#  0.0083
# -0.0243
# -0.0287
# -0.0109
# -0.0224
# -0.0303
#  0.0154
#  0.0057
# -0.0111
# -0.0103
#  0.0008
#  0.0060
# -0.0071
#  0.0086
# -0.0004
# -0.0020
# -0.0071
# -0.0035
# -0.0087
# -0.0152
# -0.0064
# -0.0117
# -0.0103
#  0.0090
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0104
#  0.0132
#  0.0132
#  0.0123
#  0.0151
#  0.0202
# -0.0030
#  0.0080
#  0.0159
# [ torch.HalfTensor{9216} ]
# [2024-03-22 00:56:37,753] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 18706
# [2024-03-22 00:56:37,753] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 18707
# [2024-03-22 00:56:37,753] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 18708
# [2024-03-22 00:56:37,753] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 18709
# [2024-03-22 00:56:37,753] [ERROR] [launch.py:184:sigkill_handler] ['/usr/bin/python', '-u', '/dli/code/moe/large_model_deepspeed.py', '--local_rank=3', '--deepspeed', '--deepspeed_config', '/dli/code/moe/ds_config_stage_3.json', '--profile-execution=True', '--profile-name=zero_resnet152_stage3'] exits with return code = 1

# %% [markdown]
# Execute the next cell to create a link to Tensorboard in your browser.

# %%
# %%js
# const href = window.location.hostname +'/tensorboard/';
# let a = document.createElement('a');
# let link = document.createTextNode('Open Tensorboard!');
# a.appendChild(link);
# a.href = "http://" + href;
# a.style.color = "navy"
# a.target = "_blank"
# element.append(a);

# %% [markdown]
# ### Exercise: ZeRO Stage 1
#
# Compare ZeRO Stage 1 execution time and GPU/CPU memory to no ZeRO and ZeRO Stage 3 + Offload. We have already prepared the DeepSpeed configuration file. Let's have a look:

# %%
# Show DeepSpeed config file for Zero stage 1 
# !cat /dli/code/moe/ds_config_stage_1.json
# Out:
# {
#   "train_batch_size": 512,
#   "steps_per_print": 2000,
#   "optimizer": {
#     "type": "Adam",
#     "params": {
#       "lr": 0.001,
#       "betas": [
#         0.8,
#         0.999
#       ],
#       "eps": 1e-8,
#       "weight_decay": 3e-7
#     }
#   },
#   "scheduler": {
#     "type": "WarmupLR",
#     "params": {
#       "warmup_min_lr": 0,
#       "warmup_max_lr": 0.001,
#       "warmup_num_steps": 1000
#     }
#   },
#   "gradient_clipping": 1.0,
#   "prescale_gradients": false,
#   "fp16": {
#       "enabled": true,
#       "fp16_master_weights_and_grads": false,
#       "loss_scale": 0,
#       "loss_scale_window": 500,
#       "hysteresis": 2,
#       "min_loss_scale": 1,
#       "initial_scale_power": 15
#   },
#   "wall_clock_breakdown": false,
#   "activation_checkpointing": {
#       "partition_activations": false,
#       "cpu_checkpointing": false,
#       "contiguous_memory_optimization": false,
#       "number_checkpoints": 24,
#       "synchronize_checkpoint_boundary": false,
#       "profile": false
#     },
#   "zero_optimization": {
#       "stage": 1,
#       "allgather_partitions": true,
#       "reduce_scatter": true,
#       "allgather_bucket_size": 50000000,
#       "reduce_bucket_size": 50000000,
#       "overlap_comm": true,
#       "contiguous_gradients": true,
#       "cpu_offload": false
#   }
# }

# %% [markdown]
# Execute the next cell to run the *resnet152* model training on the CIFAR-10 dataset with ZeRO Stage1. Replace the `FIXME` with the corresponding arguments. If you get stuck, you can look at the [solution](solutions/ex5.2.4.ipynb).

# %%
# !deepspeed --num_gpus=4 /dli/code/moe/large_model_deepspeed.py \
    --deepspeed \
    --deepspeed_config /dli/code/moe/ds_config_stage_1.json \
    --profile-execution=True \
    --profile-name='zero_resnet152_stage1'
# Out:
# [2024-03-22 01:00:33,443] [WARNING] [runner.py:159:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2024-03-22 01:00:33,495] [INFO] [runner.py:457:main] cmd = /usr/bin/python -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMSwgMiwgM119 --master_addr=127.0.0.1 --master_port=29500 /dli/code/moe/large_model_deepspeed.py --deepspeed --deepspeed_config /dli/code/moe/ds_config_stage_1.json --profile-execution=True --profile-name=zero_resnet152_stage1
# [2024-03-22 01:00:35,277] [INFO] [launch.py:96:main] 0 NCCL_P2P_DISABLE=1
# [2024-03-22 01:00:35,278] [INFO] [launch.py:96:main] 0 NCCL_VERSION=2.15.5
# [2024-03-22 01:00:35,278] [INFO] [launch.py:103:main] WORLD INFO DICT: {'localhost': [0, 1, 2, 3]}
# [2024-03-22 01:00:35,278] [INFO] [launch.py:109:main] nnodes=1, num_local_procs=4, node_rank=0
# [2024-03-22 01:00:35,278] [INFO] [launch.py:122:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1, 2, 3]})
# [2024-03-22 01:00:35,278] [INFO] [launch.py:123:main] dist_world_size=4
# [2024-03-22 01:00:35,278] [INFO] [launch.py:125:main] Setting CUDA_VISIBLE_DEVICES=0,1,2,3
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [2024-03-22 01:00:47,517] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-22 01:00:47,721] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-22 01:00:47,725] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2024-03-22 01:00:47,781] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2024-03-22 01:00:47,914] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torch/distributed/distributed_c10d.py:433: UserWarning: torch.distributed.distributed_c10d._get_global_rank is deprecated please use torch.distributed.distributed_c10d.get_global_rank instead
#   warnings.warn(
# [2024-03-22 01:00:59,888] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.11954307556152344 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10200977325439453 seconds
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10218071937561035 seconds
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10221314430236816 seconds
# [2024-03-22 01:01:00,702] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# [2024-03-22 01:01:00,727] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = FusedAdam
# [2024-03-22 01:01:00,727] [INFO] [utils.py:52:is_zero_supported_optimizer] Checking ZeRO support for optimizer=FusedAdam type=<class 'deepspeed.ops.adam.fused_adam.FusedAdam'>
# [2024-03-22 01:01:00,727] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 ZeRO stage 1 optimizer
# [2024-03-22 01:01:00,727] [INFO] [stage_1_and_2.py:133:__init__] Reduce bucket size 50000000
# [2024-03-22 01:01:00,727] [INFO] [stage_1_and_2.py:134:__init__] Allgather bucket size 50000000
# [2024-03-22 01:01:00,727] [INFO] [stage_1_and_2.py:135:__init__] CPU Offload: False
# [2024-03-22 01:01:00,728] [INFO] [stage_1_and_2.py:136:__init__] Round robin gradient partitioning: False
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.11657404899597168 seconds
# Time to load utils op: 0.10191893577575684 seconds
# Loading extension module utils...
# Time to load utils op: 0.1019899845123291 seconds
# Loading extension module utils...
# Time to load utils op: 0.11384010314941406 seconds
# Rank: 2 partition count [4] and sizes[(15048202, False)]
# Rank: 1 partition count [4] and sizes[(15048202, False)]
# Rank: 3 partition count [4] and sizes[(15048202, False)]
# Rank: 0 partition count [4] and sizes[(15048202, False)]
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0006957054138183594 seconds
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0008034706115722656 seconds
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0017974376678466797 seconds
# [2024-03-22 01:01:10,237] [INFO] [utils.py:828:see_memory_usage] Before initializing optimizer states
# [2024-03-22 01:01:10,238] [INFO] [utils.py:829:see_memory_usage] MA 0.17 GB         Max_MA 0.2 GB         CA 0.32 GB         Max_CA 0 GB
# [2024-03-22 01:01:10,239] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 19.57 GB, percent = 2.3%
# [2024-03-22 01:01:10,320] [INFO] [utils.py:828:see_memory_usage] After initializing optimizer states
# [2024-03-22 01:01:10,320] [INFO] [utils.py:829:see_memory_usage] MA 0.28 GB         Max_MA 0.34 GB         CA 0.49 GB         Max_CA 0 GB
# [2024-03-22 01:01:10,321] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 19.69 GB, percent = 2.3%
# [2024-03-22 01:01:10,321] [INFO] [stage_1_and_2.py:511:__init__] optimizer state initialized
# [2024-03-22 01:01:10,389] [INFO] [utils.py:828:see_memory_usage] After initializing ZeRO optimizer
# [2024-03-22 01:01:10,389] [INFO] [utils.py:829:see_memory_usage] MA 0.28 GB         Max_MA 0.28 GB         CA 0.49 GB         Max_CA 0 GB
# [2024-03-22 01:01:10,389] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 19.69 GB, percent = 2.3%
# [2024-03-22 01:01:10,389] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2024-03-22 01:01:10,390] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2024-03-22 01:01:10,390] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7f468ad15c70>
# [2024-03-22 01:01:10,390] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2024-03-22 01:01:10,390] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# [2024-03-22 01:01:10,390] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": 24,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   amp_params ................... False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   dump_state ................... False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2024-03-22 01:01:10,391] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   pld_params ................... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   train_batch_size ............. 512
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  128
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   world_size ................... 4
# [2024-03-22 01:01:10,392] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2024-03-22 01:01:10,393] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 1,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 5.000000e+07,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+07,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": null,
#     "offload_optimizer": null,
#     "sub_group_size": 1.000000e+09,
#     "prefetch_bucket_size": 5.000000e+07,
#     "param_persistence_threshold": 1.000000e+05,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": false,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2024-03-22 01:01:10,393] [INFO] [config.py:1063:print]   zero_enabled ................. True
# [2024-03-22 01:01:10,393] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 1
# [2024-03-22 01:01:10,393] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 512,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "activation_checkpointing": {
#         "partition_activations": false,
#         "cpu_checkpointing": false,
#         "contiguous_memory_optimization": false,
#         "number_checkpoints": 24,
#         "synchronize_checkpoint_boundary": false,
#         "profile": false
#     },
#     "zero_optimization": {
#         "stage": 1,
#         "allgather_partitions": true,
#         "reduce_scatter": true,
#         "allgather_bucket_size": 5.000000e+07,
#         "reduce_bucket_size": 5.000000e+07,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "cpu_offload": false
#     }
# }
# Using /root/.cache/torch_extensions/py38_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003523826599121094 seconds
# [2024-03-22 01:01:11,821] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 32768
# [2024-03-22 01:01:12,041] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 16384.0
# STAGE:2024-03-22 01:01:12 24397:24397 ActivityProfilerController.cpp:294] Completed Stage: Warm Up
# [2024-03-22 01:01:12,136] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 16384.0, reducing to 8192.0
# STAGE:2024-03-22 01:01:12 24397:24397 ActivityProfilerController.cpp:300] Completed Stage: Collection
# STAGE:2024-03-22 01:01:12 24397:24397 output_json.cpp:417] Completed Stage: Post Processing
# [2024-03-22 01:01:13,106] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [2024-03-22 01:01:13,283] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 4096.0, reducing to 2048.0
# Training Done
# Training Done
# Training DoneTraining Done
#
# [2024-03-22 01:01:26,376] [INFO] [launch.py:210:main] Process 24399 exits successfully.
# [2024-03-22 01:01:26,376] [INFO] [launch.py:210:main] Process 24400 exits successfully.
# [2024-03-22 01:01:26,376] [INFO] [launch.py:210:main] Process 24398 exits successfully.
# [2024-03-22 01:01:27,378] [INFO] [launch.py:210:main] Process 24397 exits successfully.

# %% [markdown]
# Compared to the run without ZeRO, Stage 1 allows to reduce the GPU memory usage from about 1.1GB to 620MB as it partitions the optimizer states across 4 GPUs meaning that each GPU is responsible for keeping in memory a part of the optimizer states and communicate them when necessary to others. In this case, no significant extra time is observed to run the step with ZeRO Stage 1.

# %% [markdown]
# ## Optional: 6.2.4  Autotuning
#
# When designing training experiments, it is hard to know what are the best configurations (such as micro-batch size) that fully utilize the hardware and achieve a high throughput number. Usually, configuration exploration is performed manually. This tuning process can be painful, time-consuming and the configurations are hardware-dependent. The DeepSpeed Autotuner automatically discovers the optimal DeepSpeed configuration parameters that optimizes for training speed.
# To launch the autotuning, add `--autotuning run` command to the training script and enable it on the configuration file as follows:
#
# ```
# {
#   "train_micro_batch_size_per_gpu": "auto",
#
#   "autotuning": {
#     "enabled": true,
#     "arg_mappings": {
#       "train_micro_batch_size_per_gpu": "--batch_size"    }
#   }
# }
# ```
# The arg_mappings dictionary autotuning section of the DeepSpeed configuration file provides the naming mappings between the parameters in DeepSpeed configuration and the training script arguments. It is also possible restrict the search space to a list of values by replacing "auto" with a vector of possible values to be evaluated.
#
# To learn more about the Autotuning feature, check the [DeepSpeed documentation](https://www.deepspeed.ai/tutorials/autotuning/)

# %% [markdown]
# ---
# <h2 style="color:green;">Congratulations!</h2>
#
# Before moving on, we need to make sure no jobs are still running or waiting in the queue.

# %%
# Check the SLURM jobs queue 
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# If there are still jobs running or pending, execute the following cell to cancel all the admin user's jobs using the `scancel` command.

# %%
# Cancel admin user jobs
# !scancel -u $USER

# Check again the SLURM jobs queue (should be either empty, or the status TS column should be CG)
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# Next, we will see Mixture of Expert (MOE) configurations. Move on to [07_MOE_alternative_models.ipynb](07_MOE_alternative_models.ipynb).
